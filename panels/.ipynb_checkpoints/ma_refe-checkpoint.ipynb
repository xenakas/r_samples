# %%
df_ihh  <-  read.csv(file="raw_data.csv", header=TRUE, sep=",", row.names =1)

# %%
library('plm')

# %%
df_ihh = pdata.frame(df_ihh, index = c('otrasl','year'))

# %%
df_ihh['ma_lag'] = lag(df_ihh$MA, 1)

# %%
df_lag = lag(df_ihh$MA, 1)

# %%
df_ihh
# Out:
#                           year otrasl               TR           TR10
# IT-2013                   2013 IT                   6.690939e+11 1.508438e+11
# IT-2014                   2014 IT                   7.520101e+11 1.652843e+11
# IT-2015                   2015 IT                   8.515278e+11 1.974169e+11
# IT-2016                   2016 IT                   9.888551e+11 2.454452e+11
# IT-2017                   2017 IT                   2.755628e+12 5.227333e+10
# ДОБЫЧА-2013               2013 ДОБЫЧА               1.212809e+13 6.897735e+12
# ДОБЫЧА-2014               2014 ДОБЫЧА               1.363228e+13 7.870675e+12
# ДОБЫЧА-2015               2015 ДОБЫЧА               1.436711e+13 7.706976e+12
# ДОБЫЧА-2016               2016 ДОБЫЧА               1.462882e+13 7.647184e+12
# ДОБЫЧА-2017               2017 ДОБЫЧА               1.736623e+13 9.182911e+12
# ЛЕГКАЯ-2013               2013 ЛЕГКАЯ               2.989955e+11 8.704345e+10
# ЛЕГКАЯ-2014               2014 ЛЕГКАЯ               3.210211e+11 9.771272e+10
# ЛЕГКАЯ-2015               2015 ЛЕГКАЯ               3.528524e+11 8.931927e+10
# ЛЕГКАЯ-2016               2016 ЛЕГКАЯ               3.989259e+11 1.048226e+11
# ЛЕГКАЯ-2017               2017 ЛЕГКАЯ               4.245590e+11 1.168420e+11
# ЛЕСНАЯ-2013               2013 ЛЕСНАЯ               8.509128e+10 2.186406e+10
# ЛЕСНАЯ-2014               2014 ЛЕСНАЯ               9.989583e+10 2.341341e+10
# ЛЕСНАЯ-2015               2015 ЛЕСНАЯ               1.178227e+11 2.825675e+10
# ЛЕСНАЯ-2016               2016 ЛЕСНАЯ               1.409559e+11 3.637040e+10
# ЛЕСНАЯ-2017               2017 ЛЕСНАЯ               1.472894e+11 3.722306e+10
# МАШИНОСТРОЕНИЕ-2013       2013 МАШИНОСТРОЕНИЕ       4.043145e+12 1.140093e+12
# МАШИНОСТРОЕНИЕ-2014       2014 МАШИНОСТРОЕНИЕ       4.193064e+12 1.168890e+12
# МАШИНОСТРОЕНИЕ-2015       2015 МАШИНОСТРОЕНИЕ       4.150595e+12 1.031173e+12
# МАШИНОСТРОЕНИЕ-2016       2016 МАШИНОСТРОЕНИЕ       4.697840e+12 1.184529e+12
# МАШИНОСТРОЕНИЕ-2017       2017 МАШИНОСТРОЕНИЕ       5.421781e+12 1.446254e+12
# МЕТАЛЛУРГИЯ-2013          2013 МЕТАЛЛУРГИЯ          2.974004e+12 1.559118e+12
# МЕТАЛЛУРГИЯ-2014          2014 МЕТАЛЛУРГИЯ          3.395286e+12 1.779300e+12
# МЕТАЛЛУРГИЯ-2015          2015 МЕТАЛЛУРГИЯ          4.018272e+12 2.114788e+12
# МЕТАЛЛУРГИЯ-2016          2016 МЕТАЛЛУРГИЯ          4.107880e+12 2.162142e+12
# ДОБЫЧА-2014               0      1       16702.8700
# ДОБЫЧА-2015               1      0        8834.0300
# ДОБЫЧА-2016               1      0        6636.3700
# ДОБЫЧА-2017               1      0       33116.5200
# ЛЕГКАЯ-2013               0      0        8821.0100
# ЛЕГКАЯ-2014               0      0         208.0077
# ЛЕГКАЯ-2015               0      0         265.3476
# ЛЕГКАЯ-2016               0      0         496.7948
# ЛЕГКАЯ-2017               0      0           0.0000
# ЛЕСНАЯ-2013               0      0         150.6365
# ЛЕСНАЯ-2014               0      0        4289.8623
# ЛЕСНАЯ-2015               0      0       30328.3764
# ЛЕСНАЯ-2016               0      0        1007.8796
# ЛЕСНАЯ-2017               0      0        8773.1627
# МАШИНОСТРОЕНИЕ-2013       0      0        1417.3254
# МАШИНОСТРОЕНИЕ-2014       0      0       30922.2300
# МАШИНОСТРОЕНИЕ-2015       0      0       48730.7449
# МАШИНОСТРОЕНИЕ-2016       0      0       13179.2311
# МАШИНОСТРОЕНИЕ-2017       0      0       19155.4520
# МЕТАЛЛУРГИЯ-2013          0      0        7229.2177
# МЕТАЛЛУРГИЯ-2014          0      0       41850.3187
# МЕТАЛЛУРГИЯ-2015          0      0       33244.1157
# МЕТАЛЛУРГИЯ-2016          0      0       41652.5854
# МЕТАЛЛУРГИЯ-2017          1      0       21734.1280
# ⋮                         ⋮      ⋮      ⋮
# СТРОИТЕЛЬСТВО-2013        0      0         6147.814
# СТРОИТЕЛЬСТВО-2014        0      0       132014.393
# СТРОИТЕЛЬСТВО-2015        0      0       166421.933
# СТРОИТЕЛЬСТВО-2016        0      0       588002.646
# СТРОИТЕЛЬСТВО-2017        0      0       634563.657
# ТОРГОВЛЯ-2013             0      0       206575.839
# ТОРГОВЛЯ-2014             0      0       101930.616
# ТОРГОВЛЯ-2015             0      0        64556.575
# ТОРГОВЛЯ-2016             0      0        99239.006
# ТОРГОВЛЯ-2017             0      0       178178.229
# ТЭК-2013                  1      0        93370.215
# ТЭК-2014                  1      0      2229095.577
# ТЭК-2015                  1      0       628654.783
# ТЭК-2016                  1      0       477606.528
# ТЭК-2017                  1      0        44646.553
# УСЛУГИ-2013               0      0       808404.661
# УСЛУГИ-2014               0      0        69472.054
# УСЛУГИ-2015               0      0        77850.008
# УСЛУГИ-2016               0      0        54901.946
# УСЛУГИ-2017               0      0        53628.092
# ФИНАНСОВЫЕ ИНСТИТУТЫ-2013 0      1        85335.283
# ФИНАНСОВЫЕ ИНСТИТУТЫ-2014 0      1       103958.518
# ФИНАНСОВЫЕ ИНСТИТУТЫ-2015 0      1       126378.193
# ФИНАНСОВЫЕ ИНСТИТУТЫ-2016 0      1       150675.119
# ФИНАНСОВЫЕ ИНСТИТУТЫ-2017 0      1        67545.638
# ЭЛЕКТРОЭНЕРГЕТИКА-2013    0      0       506567.772
# ЭЛЕКТРОЭНЕРГЕТИКА-2014    0      0       117993.852
# ЭЛЕКТРОЭНЕРГЕТИКА-2015    0      0        28337.702
# ЭЛЕКТРОЭНЕРГЕТИКА-2016    0      0        16604.566
# ЭЛЕКТРОЭНЕРГЕТИКА-2017    0      0        29137.832

# %%
coplot(MA ~ year|otrasl, type="b", data=df_ihh)
# Out:
# plot without title

# %%
library(gplots)

# %%
plotmeans(MA ~ year, data = df_ihh)
# plotmeans(MA ~ otrasl, data = df_ihh)
# Out:
# plot without title

# %%
ols <-lm(MA~IHH, data = df_ihh)
summary(ols)
# Out:
# Call:
# lm(formula = MA ~ IHH, data = df_ihh)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -179921  -91816  -67980  -36579 2117017
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 93940.44   32236.81   2.914  0.00452 **
# IHH            30.70      28.18   1.089  0.27896
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 271700 on 88 degrees of freedom
# Multiple R-squared:  0.01331,	Adjusted R-squared:  0.002094
# F-statistic: 1.187 on 1 and 88 DF,  p-value: 0.279

# %%
library(ggplot2)

# %%
yhat <- ols$fitted
ggplot(df_ihh, aes(x = IHH, y = MA))+
  geom_point() 
# +
#    geom_smooth(method=lm)
# Out:
# plot without title

# %%
fixed.dum <-lm(MA~IHH + factor(otrasl) - 1, data = df_ihh)
summary(fixed.dum)
# Out:
# Call:
# lm(formula = MA ~ IHH + factor(otrasl) - 1, data = df_ihh)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -785403  -18066   -4719   11094 1389091
#
# Coefficients:
#                                      Estimate Std. Error t value Pr(>|t|)
# IHH                                    110.98      80.72   1.375 0.173475
# factor(otrasl)IT                    101031.80   93729.83   1.078 0.284725
# factor(otrasl)ДОБЫЧА                -89297.35  120324.27  -0.742 0.460451
# factor(otrasl)ЛЕГКАЯ                -16982.92   94339.76  -0.180 0.857651
# factor(otrasl)ЛЕСНАЯ                 -2976.23   93921.91  -0.032 0.974810
# factor(otrasl)МАШИНОСТРОЕНИЕ         12031.42   93899.81   0.128 0.898408
# factor(otrasl)МЕТАЛЛУРГИЯ           -12154.74   98507.72  -0.123 0.902148
# factor(otrasl)НЕФТЕХИМ               13152.53   96632.63   0.136 0.892121
# factor(otrasl)ПИЩЕВАЯ                21270.15   93590.05   0.227 0.820867
# factor(otrasl)СВЯЗЬ                -109720.23  140155.08  -0.783 0.436319
# factor(otrasl)СЕЛЬХОЗ                55492.92   93516.28   0.593 0.554797
# factor(otrasl)СМИ                   -15156.82   97579.64  -0.155 0.877004
# factor(otrasl)СПОРТ                 -24463.79   96977.31  -0.252 0.801567
# factor(otrasl)СТРОИТЕЛЬСТВО         339763.41   93599.54   3.630 0.000531 ***
# factor(otrasl)ТОРГОВЛЯ               90132.46   94350.93   0.955 0.342673
# factor(otrasl)ТЭК                   774432.94  104208.85   7.432 1.89e-10 ***
# factor(otrasl)УСЛУГИ                 58108.57   93795.74   0.620 0.537555
# factor(otrasl)ФИНАНСОВЫЕ ИНСТИТУТЫ -289669.72  361901.24  -0.800 0.426143
# factor(otrasl)ЭЛЕКТРОЭНЕРГЕТИКА      27218.29   94297.10   0.289 0.773695
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 209100 on 71 degrees of freedom
# Multiple R-squared:  0.5956,	Adjusted R-squared:  0.4873
# F-statistic: 5.503 on 19 and 71 DF,  p-value: 5.756e-08

# %%
library(car)

# %%
yhat <- fixed.dum$fitted
scatterplot(yhat ~ df_ihh$IHH | df_ihh$otrasl,  xlab ="x1", ylab ="yhat", boxplots = FALSE,smooth = FALSE)
abline(lm(df_ihh$MA~df_ihh$IHH),lwd=3, col="red")
# Out:
# Warning message in scatterplot.default(X[, 2], X[, 1], groups = X[, 3], xlab = xlab, :
# “number of groups exceeds number of available colors
#   colors are recycled”
# plot without title

# %%
fixed <- plm(MA~IHH, data = df_ihh, model="within")
summary(fixed)
# Out:
# Oneway (individual) effect Within Model
#
# Call:
# plm(formula = MA ~ IHH, data = df_ihh, model = "within")
#
# Balanced Panel: n = 18, T = 5, N = 90
#
# Residuals:
#    Min. 1st Qu.  Median 3rd Qu.    Max.
# -785403  -18066   -4719   11094 1389091
#
# Coefficients:
#     Estimate Std. Error t-value Pr(>|t|)
# IHH  110.979     80.716  1.3749   0.1735
#
# Total Sum of Squares:    3.1865e+12
# Residual Sum of Squares: 3.1039e+12
# R-Squared:      0.025935
# Adj. R-Squared: -0.22101
# F-statistic: 1.89044 on 1 and 71 DF, p-value: 0.17348

# %%
fixef(fixed)
# Out:
#                   IT               ДОБЫЧА               ЛЕГКАЯ
#           101031.803           -89297.345           -16982.921
#               ЛЕСНАЯ       МАШИНОСТРОЕНИЕ          МЕТАЛЛУРГИЯ
#            -2976.226            12031.425           -12154.744
#             НЕФТЕХИМ              ПИЩЕВАЯ                СВЯЗЬ
#            13152.527            21270.152          -109720.229
#              СЕЛЬХОЗ                  СМИ                СПОРТ
#            55492.925           -15156.816           -24463.787
#        СТРОИТЕЛЬСТВО             ТОРГОВЛЯ                  ТЭК
#           339763.409            90132.459           774432.938
#               УСЛУГИ ФИНАНСОВЫЕ ИНСТИТУТЫ    ЭЛЕКТРОЭНЕРГЕТИКА
#            58108.570          -289669.719            27218.291

# %%
pFtest(fixed, ols)
# Out:
# 	F test for individual effects
#
# data:  MA ~ IHH
# F = 4.5653, df1 = 17, df2 = 71, p-value = 2.668e-06
# alternative hypothesis: significant effects

# %% [markdown]
# p-value < 0.05 выбираем fe model

# %%
random <- plm(MA~IHH, data = df_ihh, model="random")
summary(random)
# Out:
# Oneway (individual) effect Random Effect Model
#    (Swamy-Arora's transformation)
#
# Call:
# plm(formula = MA ~ IHH, data = df_ihh, model = "random")
#
# Balanced Panel: n = 18, T = 5, N = 90
#
# Effects:
#                     var   std.dev share
# idiosyncratic 4.372e+10 2.091e+05 0.569
# individual    3.308e+10 1.819e+05 0.431
# theta: 0.5428
#
# Residuals:
#    Min. 1st Qu.  Median 3rd Qu.    Max.
# -458053  -45986  -36292  -18427 1722097
#
# Coefficients:
#              Estimate Std. Error z-value Pr(>|z|)
# (Intercept) 84897.969  52968.797  1.6028   0.1090
# IHH            47.921     41.997  1.1411   0.2538
#
# Total Sum of Squares:    3.8968e+12
# Residual Sum of Squares: 3.84e+12
# R-Squared:      0.01458
# Adj. R-Squared: 0.0033819
# Chisq: 1.30201 on 1 DF, p-value: 0.25385

# %%
phtest(fixed, random)
# Out:
# 	Hausman Test
#
# data:  MA ~ IHH
# chisq = 0.83689, df = 1, p-value = 0.3603
# alternative hypothesis: one model is inconsistent

# %% [markdown]
# p-value > 0.5 используем  RE модель

# %%
fixed.time <- plm(MA~IHH + factor(year), data=df_ihh, model="within")
summary(fixed.time)
# Out:
# Oneway (individual) effect Within Model
#
# Call:
# plm(formula = MA ~ IHH + factor(year), data = df_ihh, model = "within")
#
# Balanced Panel: n = 18, T = 5, N = 90
#
# Residuals:
#      Min.   1st Qu.    Median   3rd Qu.      Max.
# -764580.6  -42309.3    3912.8   21201.5 1331177.5
#
# Coefficients:
#                    Estimate Std. Error t-value Pr(>|t|)
# IHH                 108.643     83.622  1.2992   0.1983
# factor(year)2014 -81795.148  71018.993 -1.1517   0.2535
# factor(year)2015 -63725.447  70946.678 -0.8982   0.3723
# factor(year)2016 -78945.178  70826.471 -1.1146   0.2690
# factor(year)2017 -65345.364  71163.844 -0.9182   0.3618
#
# Total Sum of Squares:    3.1865e+12
# Residual Sum of Squares: 3.0237e+12
# R-Squared:      0.051093
# Adj. R-Squared: -0.26049
# F-statistic: 0.721507 on 5 and 67 DF, p-value: 0.6096

# %%
pFtest(fixed.time, fixed)
# Out:
# 	F test for individual effects
#
# data:  MA ~ IHH + factor(year)
# F = 0.44407, df1 = 4, df2 = 67, p-value = 0.7763
# alternative hypothesis: significant effects

# %%
plmtest(fixed, c("time"), type=("bp"))
# Out:
# 	Lagrange Multiplier Test - time effects (Breusch-Pagan) for balanced
# 	panels
#
# data:  MA ~ IHH
# chisq = 1.5561, df = 1, p-value = 0.2122
# alternative hypothesis: significant effects

# %% [markdown]
# нет фиксированных временных эффектов

# %%
pool <- plm(MA~IHH, data = df_ihh, model="pooling")
summary(pool)
# Out:
# Pooling Model
#
# Call:
# plm(formula = MA ~ IHH, data = df_ihh, model = "pooling")
#
# Balanced Panel: n = 18, T = 5, N = 90
#
# Residuals:
#    Min. 1st Qu.  Median 3rd Qu.    Max.
# -179921  -91816  -67980  -36579 2117017
#
# Coefficients:
#              Estimate Std. Error t-value Pr(>|t|)
# (Intercept) 93940.437  32236.806  2.9141 0.004523 **
# IHH            30.699     28.180  1.0894 0.278962
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Total Sum of Squares:    6.5843e+12
# Residual Sum of Squares: 6.4967e+12
# R-Squared:      0.013306
# Adj. R-Squared: 0.0020938
# F-statistic: 1.18674 on 1 and 88 DF, p-value: 0.27896

# %%
plmtest(pool, type=c("bp"))
# Out:
# 	Lagrange Multiplier Test - (Breusch-Pagan) for balanced panels
#
# data:  MA ~ IHH
# chisq = 28.01, df = 1, p-value = 1.207e-07
# alternative hypothesis: significant effects

# %% [markdown]
# p-value < 2.2e-16  используем re модель

# %%
pcdtest(fixed, test = c("lm"))
# Out:
# 	Breusch-Pagan LM test for cross-sectional dependence in panels
#
# data:  MA ~ IHH
# chisq = 191.82, df = 153, p-value = 0.01819
# alternative hypothesis: cross-sectional dependence

# %%
pcdtest(fixed, test = c("cd"))
# Out:
# 	Pesaran CD test for cross-sectional dependence in panels
#
# data:  MA ~ IHH
# z = -0.59843, p-value = 0.5496
# alternative hypothesis: cross-sectional dependence

# %% [markdown]
# p-value > 0.05 нет кросс-секциональной зависимости

# %%
pbgtest(fixed)
# Out:
# 	Breusch-Godfrey/Wooldridge test for serial correlation in panel models
#
# data:  MA ~ IHH
# chisq = 15.288, df = 5, p-value = 0.009202
# alternative hypothesis: serial correlation in idiosyncratic errors

# %% [markdown]
# Есть серийная корреляция, однако на коротких временных рядах - это не является проблемой

# %%
library(tseries)

# %%
adf.test(df_ihh$MA, k=2)
# Out:
# Warning message in adf.test(df_ihh$MA, k = 2):
# “p-value smaller than printed p-value”
# 	Augmented Dickey-Fuller Test
#
# data:  df_ihh$MA
# Dickey-Fuller = -4.7136, Lag order = 2, p-value = 0.01
# alternative hypothesis: stationary

# %% [markdown]
# p-value < 0.05 ряды не имеют единичного корня

# %%
bptest(MA~IHH, data = df_ihh, studentize=F)
# Out:
# 	Breusch-Pagan test
#
# data:  MA ~ IHH
# BP = 0.2774, df = 1, p-value = 0.5984

# %% [markdown]
# НЕТ гетероскдастичности

# %%
coeftest(random)
# Out:
# t test of coefficients:
#
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 84897.969  52968.797  1.6028   0.1126
# IHH            47.921     41.997  1.1411   0.2569

# %%
coeftest(random, vcovHC)
# Out:
# t test of coefficients:
#
#               Estimate Std. Error t value  Pr(>|t|)
# (Intercept) 84897.9691 44557.7746  1.9053      0.06 .
# IHH            47.9209     8.9991  5.3251 7.648e-07 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
coeftest(random, vcovHC(random, type = "HC3"))
# Out:
# t test of coefficients:
#
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 84897.969  46786.726  1.8146  0.07300 .
# IHH            47.921     22.241  2.1546  0.03392 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %% [markdown]
# HC3 – Recommended for small samples. HC3 gives less weight to influential observations.

# %%
random <- plm(MA~IHH+ma_lag, data = df_ihh, model="random")
summary(random)
# Out:
# Oneway (individual) effect Random Effect Model
#    (Swamy-Arora's transformation)
#
# Call:
# plm(formula = MA ~ IHH + ma_lag, data = df_ihh, model = "random")
#
# Unbalanced Panel: n = 18, T = 4-5, N = 89
#
# Effects:
#                     var   std.dev share
# idiosyncratic 4.222e+10 2.055e+05     1
# individual    0.000e+00 0.000e+00     0
# theta:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#       0       0       0       0       0       0
#
# Residuals:
#    Min. 1st Qu.  Median 3rd Qu.    Max.
# -235385  -69373  -52023  -26667 2121427
#
# Coefficients:
#               Estimate Std. Error z-value Pr(>|z|)
# (Intercept) 6.3792e+04 3.3361e+04  1.9122 0.055853 .
# IHH         2.9220e+01 2.7332e+01  1.0691 0.285031
# ma_lag      2.8501e-01 1.0265e-01  2.7766 0.005493 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Total Sum of Squares:    6.5785e+12
# Residual Sum of Squares: 5.9586e+12
# R-Squared:      0.094231
# Adj. R-Squared: 0.073166
# Chisq: 8.94691 on 2 DF, p-value: 0.011408

# %%
coeftest(random, vcovHC)
# Out:
# t test of coefficients:
#
#                Estimate  Std. Error t value Pr(>|t|)
# (Intercept)  4.3010e+02  1.6887e+02  2.5469   0.0131 *
# MA           9.8859e-04  9.0845e-04  1.0882   0.2803
# ma_lag      -2.1411e-06  5.9215e-05 -0.0362   0.9713
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
coeftest(random, vcovHC(random, type = "HC3"))
# Out:
# t test of coefficients:
#
#                Estimate  Std. Error t value Pr(>|t|)
# (Intercept)  4.3010e+02  1.8681e+02  2.3023  0.02434 *
# MA           9.8859e-04  1.1754e-03  0.8411  0.40320
# ma_lag      -2.1411e-06  6.9555e-05 -0.0308  0.97553
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
random <- plm(MA~IHH+ma_lag+real_prices+real_gdp_change, data = df_ihh, model="random")
summary(random)
# Out:
# Oneway (individual) effect Random Effect Model
#    (Swamy-Arora's transformation)
#
# Call:
# plm(formula = MA ~ IHH + ma_lag + real_prices + real_gdp_change,
#     data = df_ihh, model = "random")
#
# Unbalanced Panel: n = 18, T = 4-5, N = 89
#
# Effects:
#                     var   std.dev share
# idiosyncratic 523762697     22886     1
# individual            0         0     0
# theta:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#       0       0       0       0       0       0
#
# Residuals:
#     Min.  1st Qu.   Median  3rd Qu.     Max.
# -78653.6  -7270.7  -2742.7   1232.2 139885.3
#
# Coefficients:
#                    Estimate  Std. Error z-value Pr(>|z|)
# (Intercept)      3.5697e+03  3.2217e+03  1.1080  0.26786
# IHH              4.8137e+00  2.5726e+00  1.8711  0.06133 .
# ma_lag           1.9249e-02  9.9865e-03  1.9275  0.05392 .
# real_prices      1.0331e+00  1.0485e-02 98.5355  < 2e-16 ***
# real_gdp_change -2.5979e+00  2.2063e+00 -1.1775  0.23901
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Total Sum of Squares:    6.5785e+12
# Residual Sum of Squares: 5.1035e+10
# R-Squared:      0.99224
# Adj. R-Squared: 0.99187
# Chisq: 10743.8 on 4 DF, p-value: < 2.22e-16

# %%
coeftest(random, vcovHC)
# Out:
# t test of coefficients:
#
#                    Estimate  Std. Error t value  Pr(>|t|)
# (Intercept)     3569.698831 2927.304392  1.2194  0.226087
# IHH                4.813651    1.414915  3.4021  0.001026 **
# ma_lag             0.019249    0.007401  2.6008  0.010988 *
# real_prices        1.033104    0.016988 60.8133 < 2.2e-16 ***
# real_gdp_change   -2.597891    1.414758 -1.8363  0.069854 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
coeftest(random, vcovHC(random, type = "HC3"))
# Out:
# t test of coefficients:
#
#                    Estimate  Std. Error t value Pr(>|t|)
# (Intercept)     3569.698831 8837.646102  0.4039   0.6873
# IHH                4.813651    4.513571  1.0665   0.2893
# ma_lag             0.019248    0.020317  0.9474   0.3462
# real_prices        1.033104    0.164595  6.2766 1.45e-08 ***
# real_gdp_change   -2.597891    2.105234 -1.2340   0.2206
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
colnames(df_ihh)
# Out:
#  [1] "year"            "otrasl"          "TR"              "TR10"
#  [5] "TR50"            "TR100"           "TR10."           "CR.10."
#  [9] "CR.50."          "CR.100."         "CR10."           "IHH"
# [13] "MA"              "real_prices"     "real_gdp_change" "market_type"
# [17] "type_1"          "type_2"          "type_3"          "type_4"
# [21] "ma_lag"

# %%
random <- plm(MA~IHH+ma_lag+real_prices+real_gdp_change+market_type, data = df_ihh, model="random")
summary(random)
# Out:
# Oneway (individual) effect Random Effect Model
#    (Swamy-Arora's transformation)
#
# Call:
# plm(formula = MA ~ IHH + ma_lag + real_prices + real_gdp_change +
#     market_type, data = df_ihh, model = "random")
#
# Unbalanced Panel: n = 18, T = 4-5, N = 89
#
# Effects:
#                     var   std.dev share
# idiosyncratic 531109385     23046     1
# individual            0         0     0
# theta:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#       0       0       0       0       0       0
#
# Residuals:
#     Min.  1st Qu.   Median  3rd Qu.     Max.
# -75199.7  -6413.0  -1936.6   1143.7 145568.8
#
# Coefficients:
#                    Estimate  Std. Error z-value Pr(>|z|)
# (Intercept)      8.1808e+03  4.1967e+03  1.9494  0.05125 .
# IHH              8.7009e+00  3.4315e+00  2.5356  0.01122 *
# ma_lag           2.0571e-02  9.9092e-03  2.0759  0.03790 *
# real_prices      1.0344e+00  1.0399e-02 99.4692  < 2e-16 ***
# real_gdp_change -2.5020e+00  2.1832e+00 -1.1460  0.25178
# market_type     -4.4978e+03  2.6635e+03 -1.6887  0.09129 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Total Sum of Squares:    6.5785e+12
# Residual Sum of Squares: 4.934e+10
# R-Squared:      0.9925
# Adj. R-Squared: 0.99205
# Chisq: 10983.4 on 5 DF, p-value: < 2.22e-16

# %%
coeftest(random, vcovHC)
# Out:
# t test of coefficients:
#
#                    Estimate  Std. Error t value  Pr(>|t|)
# (Intercept)      8.1808e+03  3.0081e+03  2.7196  0.007959 **
# IHH              8.7009e+00  1.8195e+00  4.7821 7.428e-06 ***
# ma_lag           2.0571e-02  6.8917e-03  2.9848  0.003727 **
# real_prices      1.0344e+00  1.5699e-02 65.8900 < 2.2e-16 ***
# real_gdp_change -2.5020e+00  1.3700e+00 -1.8263  0.071403 .
# market_type     -4.4978e+03  2.8736e+03 -1.5652  0.121347
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
coeftest(random, vcovHC(random, type = "HC3"))
# Out:
# t test of coefficients:
#
#                    Estimate  Std. Error t value  Pr(>|t|)
# (Intercept)      8.1808e+03  1.0869e+04  0.7527    0.4538
# IHH              8.7009e+00  6.0972e+00  1.4270    0.1573
# ma_lag           2.0571e-02  2.3465e-02  0.8766    0.3832
# real_prices      1.0344e+00  1.6285e-01  6.3518 1.081e-08 ***
# real_gdp_change -2.5020e+00  2.1142e+00 -1.1835    0.2400
# market_type     -4.4978e+03  3.3872e+03 -1.3279    0.1879
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
df_ihh$real_prices[df_ihh$real_prices == 0] <- NA

# %%
random <- plm(MA~IHH+ma_lag+log(real_prices)+real_gdp_change+market_type, data = df_ihh, model="random")
summary(random)
# Out:
# Oneway (individual) effect Random Effect Model
#    (Swamy-Arora's transformation)
#
# Call:
# plm(formula = MA ~ IHH + ma_lag + log(real_prices) + real_gdp_change +
#     market_type, data = df_ihh, model = "random")
#
# Unbalanced Panel: n = 18, T = 4-5, N = 88
#
# Effects:
#                     var   std.dev share
# idiosyncratic 3.261e+10 1.806e+05     1
# individual    0.000e+00 0.000e+00     0
# theta:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#       0       0       0       0       0       0
#
# Residuals:
#      Min.   1st Qu.    Median   3rd Qu.      Max.
# -213130.8  -91093.5  -58785.0    8930.7 1677827.6
#
# Coefficients:
#                     Estimate  Std. Error z-value  Pr(>|z|)
# (Intercept)      -8.4789e+05  1.6341e+05 -5.1886 2.119e-07 ***
# IHH              -3.1317e+01  3.3168e+01 -0.9442    0.3451
# ma_lag            6.4551e-02  9.7167e-02  0.6643    0.5065
# log(real_prices)  8.8844e+04  1.5741e+04  5.6440 1.661e-08 ***
# real_gdp_change   5.0640e+00  2.0418e+01  0.2480    0.8041
# market_type       3.5489e+04  2.5127e+04  1.4124    0.1578
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Total Sum of Squares:    6.5661e+12
# Residual Sum of Squares: 4.2683e+12
# R-Squared:      0.34995
# Adj. R-Squared: 0.31032
# Chisq: 44.1448 on 5 DF, p-value: 2.1646e-08

# %%
coeftest(random, vcovHC)
# Out:
# t test of coefficients:
#
#                     Estimate  Std. Error t value Pr(>|t|)
# (Intercept)      -8.4789e+05  5.6261e+05 -1.5071  0.13564
# IHH              -3.1317e+01  5.4039e+01 -0.5795  0.56382
# ma_lag            6.4551e-02  1.2608e-01  0.5120  0.61005
# log(real_prices)  8.8844e+04  5.3247e+04  1.6685  0.09903 .
# real_gdp_change   5.0640e+00  1.5282e+01  0.3314  0.74122
# market_type       3.5489e+04  4.6986e+04  0.7553  0.45223
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
coeftest(random, vcovHC(random, type = "HC3"))
# Out:
# t test of coefficients:
#
#                     Estimate  Std. Error t value Pr(>|t|)
# (Intercept)      -8.4789e+05  6.4353e+05 -1.3176   0.1913
# IHH              -3.1317e+01  6.5759e+01 -0.4762   0.6352
# ma_lag            6.4551e-02  1.0142e-01  0.6365   0.5262
# log(real_prices)  8.8844e+04  6.0469e+04  1.4693   0.1456
# real_gdp_change   5.0640e+00  1.7443e+01  0.2903   0.7723
# market_type       3.5489e+04  5.5541e+04  0.6390   0.5246

# %%
colnames(df_ihh)
# Out:
#  [1] "year"            "otrasl"          "TR"              "TR10"
#  [5] "TR50"            "TR100"           "TR10."           "CR.10."
#  [9] "CR.50."          "CR.100."         "CR10."           "IHH"
# [13] "MA"              "real_prices"     "real_gdp_change" "market_type"
# [17] "type_1"          "type_2"          "type_3"          "type_4"
# [21] "ma_lag"

# %%
random <- plm(MA~IHH+ma_lag+real_prices+real_gdp_change+type_1+type_2+type_3+type_4, data = df_ihh, model="random")
summary(random)
# Out:
# Oneway (individual) effect Random Effect Model
#    (Swamy-Arora's transformation)
#
# Call:
# plm(formula = MA ~ IHH + ma_lag + real_prices + real_gdp_change +
#     type_1 + type_2 + type_3 + type_4, data = df_ihh, model = "random")
#
# Unbalanced Panel: n = 18, T = 4-5, N = 88
#
# Effects:
#                     var   std.dev share
# idiosyncratic 553987316     23537     1
# individual            0         0     0
# theta:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#       0       0       0       0       0       0
#
# Residuals:
#     Min.  1st Qu.   Median  3rd Qu.     Max.
# -73482.1  -8854.0  -1896.4   3148.0 137362.3
#
# Coefficients:
#                    Estimate  Std. Error z-value Pr(>|z|)
# (Intercept)      1.0565e+04  5.2224e+03  2.0230  0.04307 *
# IHH              9.6827e+00  4.3336e+00  2.2343  0.02546 *
# ma_lag           1.6858e-02  1.0306e-02  1.6358  0.10189
# real_prices      1.0282e+00  1.1244e-02 91.4451  < 2e-16 ***
# real_gdp_change -2.3917e+00  2.2133e+00 -1.0806  0.27987
# type_1          -7.4426e+03  7.2527e+03 -1.0262  0.30481
# type_2          -1.5064e+04  7.6222e+03 -1.9764  0.04811 *
# type_3          -4.2267e+03  1.0345e+04 -0.4086  0.68287
# type_4          -2.4084e+04  1.4456e+04 -1.6661  0.09570 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Total Sum of Squares:    6.5661e+12
# Residual Sum of Squares: 4.7878e+10
# R-Squared:      0.99271
# Adj. R-Squared: 0.99197
# Chisq: 10755.2 on 8 DF, p-value: < 2.22e-16

# %%
coeftest(random, vcovHC)
# Out:
# t test of coefficients:
#
#                    Estimate  Std. Error t value  Pr(>|t|)
# (Intercept)      1.0565e+04  5.0362e+03  2.0978  0.039115 *
# IHH              9.6827e+00  2.1815e+00  4.4385 2.903e-05 ***
# ma_lag           1.6858e-02  1.0583e-02  1.5930  0.115151
# real_prices      1.0282e+00  2.1807e-02 47.1520 < 2.2e-16 ***
# real_gdp_change -2.3917e+00  1.3397e+00 -1.7853  0.078046 .
# type_1          -7.4426e+03  5.6317e+03 -1.3216  0.190128
# type_2          -1.5064e+04  5.6109e+03 -2.6848  0.008839 **
# type_3          -4.2267e+03  1.7419e+04 -0.2426  0.808913
# type_4          -2.4084e+04  9.8212e+03 -2.4523  0.016400 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
coeftest(random, vcovHC(random, type = "HC3"))
# Out:
# t test of coefficients:
#
#                    Estimate  Std. Error t value  Pr(>|t|)
# (Intercept)      1.0565e+04  1.5302e+04  0.6904    0.4920
# IHH              9.6827e+00  9.1953e+00  1.0530    0.2956
# ma_lag           1.6858e-02  1.6870e-02  0.9993    0.3207
# real_prices      1.0282e+00  1.7065e-01  6.0255 5.066e-08 ***
# real_gdp_change -2.3917e+00  1.8891e+00 -1.2661    0.2092
# type_1          -7.4426e+03  1.0218e+04 -0.7283    0.4686
# type_2          -1.5064e+04  1.3849e+04 -1.0877    0.2800
# type_3          -4.2267e+03  1.5592e+04 -0.2711    0.7870
# type_4          -2.4084e+04  2.5393e+04 -0.9485    0.3458
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %% [markdown]
# Кратко:
#
# a = '4'
# raw.loc[raw[raw.IHH>=1000].index, 'market_type'] =   a
#
# a = '3'
# raw.loc[raw[(raw.IHH<1000) &  (raw.IHH>=400)].index, 'market_type'] =   a
#
# a = '2'
# raw.loc[raw[(raw.IHH<400) &  (raw.IHH>=200)].index, 'market_type'] =   a
#
# a = '1'
# raw.loc[raw[(raw.IHH<200) &  (raw.IHH>=100)].index, 'market_type'] =   a
#
# a = '0'
# raw.loc[raw[(raw.IHH<100)].index, 'market_type'] =   a
#
# - Для анализа была выбрана RE модель
# - Перемнна market_type - пять значений - и соответсвенно 4 дамми для модели
#     - IHH>=1000
#     - (IHH<1000) &  (IHH>=400)
#     - (IHH<400) &  (IHH>=200)
#     - (IHH<200) &  (IHH>=100)
#     - IHH<100
# - Из-за наличия гетероскедастичности необходимо использовать устойчивые к гетероскедастичности оценки ковариационной матрицы
# - Если мы не применяем устойчивые оценки, для некоторых из моделей коэффициент при MA значимый, инчаче значимым остается только Intercept  и market_type (или дамми для типа рынка)
# - IHH ни от цены сделки, ни от логарифма цены, ни от изменения реального ВВП

# %% [markdown]
# В качестве альтернативы можно попрбоватать проверить завсимость логарифма IHH от логарифа MA (расчеты в следующем файле):

# %%
yhat <- ols$fitted
ggplot(df_ihh, aes(x = log(MA), y = log(IHH)))+
  geom_point() 
# + 
#     geom_smooth(method=lm)
# Out:
# plot without title

# %%
df_ihh[df_ihh == 0]  <- NA

# %% [markdown]
# В этой модели также есть гетероскедастичность, однако даже при использовании робастных оценок,
# значимыми остаются дамми для каждого типа рынка.
