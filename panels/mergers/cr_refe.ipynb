# %%
df_ihh  <-  read.csv(file="raw_data.csv", header=TRUE, sep=",", row.names =1)

# %%
df_ihh$MA[df_ihh$MA == 0] <- NA
df_ihh['log_ihh'] = log(df_ihh$IHH)
df_ihh['log_ma'] = log(df_ihh$MA)

# %%
library('plm')

# %%
df_ihh = pdata.frame(df_ihh, index = c('otrasl','year'))

# %%
df_ihh['ma_lag'] = lag(df_ihh$MA, 1)

# %%
df_lag = lag(df_ihh$MA, 1)

# %%
df_ihh
# Out:
#                           year otrasl               TR           TR10
# IT-2013                   2013 IT                   6.690939e+11 1.508438e+11
# IT-2014                   2014 IT                   7.520101e+11 1.652843e+11
# IT-2015                   2015 IT                   8.515278e+11 1.974169e+11
# IT-2016                   2016 IT                   9.888551e+11 2.454452e+11
# IT-2017                   2017 IT                   2.755628e+12 5.227333e+10
# ДОБЫЧА-2013               2013 ДОБЫЧА               1.212809e+13 6.897735e+12
# ДОБЫЧА-2014               2014 ДОБЫЧА               1.363228e+13 7.870675e+12
# ДОБЫЧА-2015               2015 ДОБЫЧА               1.436711e+13 7.706976e+12
# ДОБЫЧА-2016               2016 ДОБЫЧА               1.462882e+13 7.647184e+12
# ДОБЫЧА-2017               2017 ДОБЫЧА               1.736623e+13 9.182911e+12
# ЛЕГКАЯ-2013               2013 ЛЕГКАЯ               2.989955e+11 8.704345e+10
# ЛЕГКАЯ-2014               2014 ЛЕГКАЯ               3.210211e+11 9.771272e+10
# ЛЕГКАЯ-2015               2015 ЛЕГКАЯ               3.528524e+11 8.931927e+10
# ЛЕГКАЯ-2016               2016 ЛЕГКАЯ               3.989259e+11 1.048226e+11
# ЛЕГКАЯ-2017               2017 ЛЕГКАЯ               4.245590e+11 1.168420e+11
# ЛЕСНАЯ-2013               2013 ЛЕСНАЯ               8.509128e+10 2.186406e+10
# ЛЕСНАЯ-2014               2014 ЛЕСНАЯ               9.989583e+10 2.341341e+10
# ЛЕСНАЯ-2015               2015 ЛЕСНАЯ               1.178227e+11 2.825675e+10
# ЛЕСНАЯ-2016               2016 ЛЕСНАЯ               1.409559e+11 3.637040e+10
# ЛЕСНАЯ-2017               2017 ЛЕСНАЯ               1.472894e+11 3.722306e+10
# МАШИНОСТРОЕНИЕ-2013       2013 МАШИНОСТРОЕНИЕ       4.043145e+12 1.140093e+12
# МАШИНОСТРОЕНИЕ-2014       2014 МАШИНОСТРОЕНИЕ       4.193064e+12 1.168890e+12
# МАШИНОСТРОЕНИЕ-2015       2015 МАШИНОСТРОЕНИЕ       4.150595e+12 1.031173e+12
# МАШИНОСТРОЕНИЕ-2016       2016 МАШИНОСТРОЕНИЕ       4.697840e+12 1.184529e+12
# МАШИНОСТРОЕНИЕ-2017       2017 МАШИНОСТРОЕНИЕ       5.421781e+12 1.446254e+12
# МЕТАЛЛУРГИЯ-2013          2013 МЕТАЛЛУРГИЯ          2.974004e+12 1.559118e+12
# МЕТАЛЛУРГИЯ-2014          2014 МЕТАЛЛУРГИЯ          3.395286e+12 1.779300e+12
# МЕТАЛЛУРГИЯ-2015          2015 МЕТАЛЛУРГИЯ          4.018272e+12 2.114788e+12
# МЕТАЛЛУРГИЯ-2016          2016 МЕТАЛЛУРГИЯ          4.107880e+12 2.162142e+12
# МЕТАЛЛУРГИЯ-2017          2017 МЕТАЛЛУРГИЯ          4.659436e+12 2.502536e+12
# ⋮                         ⋮    ⋮                    ⋮            ⋮
# СТРОИТЕЛЬСТВО-2013        2013 СТРОИТЕЛЬСТВО        5.391777e+12 9.104382e+11
# СТРОИТЕЛЬСТВО-2014        2014 СТРОИТЕЛЬСТВО        5.822222e+12 9.181589e+11
# СТРОИТЕЛЬСТВО-2015        2015 СТРОИТЕЛЬСТВО        6.049079e+12 1.006904e+12
# СТРОИТЕЛЬСТВО-2016        2016 СТРОИТЕЛЬСТВО        6.314362e+12 1.153579e+12
# СТРОИТЕЛЬСТВО-2017        2017 СТРОИТЕЛЬСТВО        6.876638e+12 1.288722e+12
# ТОРГОВЛЯ-2013             2013 ТОРГОВЛЯ             3.150933e+13 8.541037e+12
# ТОРГОВЛЯ-2014             2014 ТОРГОВЛЯ             3.592639e+13 9.443409e+12
# ТОРГОВЛЯ-2015             2015 ТОРГОВЛЯ             3.898449e+13 1.039049e+13
# ТОРГОВЛЯ-2016             2016 ТОРГОВЛЯ             4.229658e+13 1.045008e+13
# ТОРГОВЛЯ-2017             2017 ТОРГОВЛЯ             4.573657e+13 1.143512e+13
# ТЭК-2013                  2013 ТЭК                  1.581378e+13 6.956084e+12
# ТЭК-2014                  2014 ТЭК                  1.762635e+13 7.918348e+12
# ТЭК-2015                  2015 ТЭК                  1.849451e+13 7.783137e+12
# ТЭК-2016                  2016 ТЭК                  1.918294e+13 7.731003e+12
# ТЭК-2017                  2017 ТЭК                  2.223888e+13 9.307483e+12
# УСЛУГИ-2013               2013 УСЛУГИ               3.669311e+12 9.884454e+11
# УСЛУГИ-2014               2014 УСЛУГИ               3.223338e+12 2.982690e+11
# УСЛУГИ-2015               2015 УСЛУГИ               3.605471e+12 4.168596e+11
# УСЛУГИ-2016               2016 УСЛУГИ               3.883503e+12 4.871894e+11
# УСЛУГИ-2017               2017 УСЛУГИ               4.034253e+12 4.298337e+11
# ФИНАНСОВЫЕ ИНСТИТУТЫ-2013 2013 ФИНАНСОВЫЕ ИНСТИТУТЫ 2.523278e+13 2.220324e+13
# ФИНАНСОВЫЕ ИНСТИТУТЫ-2014 2014 ФИНАНСОВЫЕ ИНСТИТУТЫ 2.072375e+13 1.704654e+13
# ФИНАНСОВЫЕ ИНСТИТУТЫ-2015 2015 ФИНАНСОВЫЕ ИНСТИТУТЫ 2.609533e+13 2.282755e+13
# ФИНАНСОВЫЕ ИНСТИТУТЫ-2016 2016 ФИНАНСОВЫЕ ИНСТИТУТЫ 3.444567e+13 3.023718e+13
# ФИНАНСОВЫЕ ИНСТИТУТЫ-2017 2017 ФИНАНСОВЫЕ ИНСТИТУТЫ 5.000410e+13 4.608994e+13
# ЭЛЕКТРОЭНЕРГЕТИКА-2013    2013 ЭЛЕКТРОЭНЕРГЕТИКА    4.754587e+12 1.481120e+12
# ЭЛЕКТРОЭНЕРГЕТИКА-2014    2014 ЭЛЕКТРОЭНЕРГЕТИКА    5.138311e+12 1.551845e+12
# ЭЛЕКТРОЭНЕРГЕТИКА-2015    2015 ЭЛЕКТРОЭНЕРГЕТИКА    5.556288e+12 1.703103e+12
# ЭЛЕКТРОЭНЕРГЕТИКА-2016    2016 ЭЛЕКТРОЭНЕРГЕТИКА    6.110765e+12 1.910985e+12
# ЭЛЕКТРОЭНЕРГЕТИКА-2017    2017 ЭЛЕКТРОЭНЕРГЕТИКА    6.659061e+12 2.108636e+12
#                           TR50         TR100        TR10.        CR.10.
# IT-2013                   2.786565e+11 3.502026e+11 4.995890e+11 0.22544485
# IT-2014                   3.141786e+11 3.924966e+11 5.607147e+11 0.21978999
# IT-2015                   3.688624e+11 4.584403e+11 6.452505e+11 0.23183846
# IT-2016                   4.611053e+11 5.574520e+11 7.653912e+11 0.24821145
# IT-2017                   1.566990e+11 2.251471e+11 3.832051e+11 0.06951148
# ДОБЫЧА-2013               1.002198e+13 1.091798e+13 1.133200e+13 0.56874019
# ДОБЫЧА-2014               1.127471e+13 1.229608e+13 1.274206e+13 0.57735556
# ДОБЫЧА-2015               1.164553e+13 1.279458e+13 1.331185e+13 0.53643183
# ДОБЫЧА-2016               1.168457e+13 1.292996e+13 1.347955e+13 0.52274772
# ДОБЫЧА-2017               1.384570e+13 1.533134e+13 1.601985e+13 0.52877986
# ЛЕГКАЯ-2013               1.487952e+11 1.816972e+11 2.112011e+11 0.29111957
# ЛЕГКАЯ-2014               1.616023e+11 1.969736e+11 2.277990e+11 0.30438094
# ЛЕГКАЯ-2015               1.706461e+11 2.123165e+11 2.493200e+11 0.25313493
# ЛЕГКАЯ-2016               1.990449e+11 2.443926e+11 2.844255e+11 0.26276200
# ЛЕГКАЯ-2017               2.173333e+11 2.674574e+11 3.086482e+11 0.27520780
# ЛЕСНАЯ-2013               4.378886e+10 5.629743e+10 5.091613e+10 0.25694827
# ЛЕСНАЯ-2014               4.991154e+10 6.491898e+10 5.875256e+10 0.23437825
# ЛЕСНАЯ-2015               5.995788e+10 7.720870e+10 7.007332e+10 0.23982443
# ЛЕСНАЯ-2016               7.542787e+10 9.560297e+10 8.707850e+10 0.25802687
# ЛЕСНАЯ-2017               8.032672e+10 1.006709e+11 9.201607e+10 0.25272057
# МАШИНОСТРОЕНИЕ-2013       2.191271e+12 2.628019e+12 3.498066e+12 0.28198180
# МАШИНОСТРОЕНИЕ-2014       2.239981e+12 2.704132e+12 3.610983e+12 0.27876742
# МАШИНОСТРОЕНИЕ-2015       2.117357e+12 2.568725e+12 3.522610e+12 0.24843982
# МАШИНОСТРОЕНИЕ-2016       2.430407e+12 2.932361e+12 4.006946e+12 0.25214325
# МАШИНОСТРОЕНИЕ-2017       2.877392e+12 3.461919e+12 4.676447e+12 0.26674890
# МЕТАЛЛУРГИЯ-2013          2.558146e+12 2.815708e+12 2.593872e+12 0.52424900
# МЕТАЛЛУРГИЯ-2014          2.936479e+12 3.214533e+12 2.975922e+12 0.52405016
# МЕТАЛЛУРГИЯ-2015          3.461059e+12 3.802915e+12 3.508021e+12 0.52629291
# МЕТАЛЛУРГИЯ-2016          3.511038e+12 3.874686e+12 3.566049e+12 0.52634016
# МЕТАЛЛУРГИЯ-2017          3.978215e+12 4.397119e+12 4.033652e+12 0.53708999
# ⋮                         ⋮            ⋮            ⋮            ⋮
# СТРОИТЕЛЬСТВО-2013        1.762479e+12 2.263560e+12 3.950037e+12 0.16885680
# СТРОИТЕЛЬСТВО-2014        1.855656e+12 2.346726e+12 4.139103e+12 0.15769905
# СТРОИТЕЛЬСТВО-2015        1.916036e+12 2.444189e+12 4.318384e+12 0.16645567
# СТРОИТЕЛЬСТВО-2016        2.079106e+12 2.558328e+12 4.493251e+12 0.18269124
# СТРОИТЕЛЬСТВО-2017        2.252745e+12 2.786989e+12 4.926598e+12 0.18740579
# ТОРГОВЛЯ-2013             1.292927e+13 1.534363e+13 2.411001e+13 0.27106377
# ТОРГОВЛЯ-2014             1.460927e+13 1.736960e+13 2.719473e+13 0.26285434
# ТОРГОВЛЯ-2015             1.595051e+13 1.878634e+13 2.935617e+13 0.26652889
# ТОРГОВЛЯ-2016             1.693518e+13 1.991229e+13 3.140674e+13 0.24706669
# ТОРГОВЛЯ-2017             1.803863e+13 2.140977e+13 3.399394e+13 0.25002149
# ТЭК-2013                  1.105005e+13 1.288696e+13 1.429762e+13 0.43987484
# ТЭК-2014                  1.234503e+13 1.430319e+13 1.590929e+13 0.44923362
# ТЭК-2015                  1.277336e+13 1.486879e+13 1.658045e+13 0.42083499
# ТЭК-2016                  1.286927e+13 1.521787e+13 1.709259e+13 0.40301449
# ТЭК-2017                  1.513267e+13 1.773600e+13 1.985576e+13 0.41852294
# УСЛУГИ-2013               1.360806e+12 1.585413e+12 2.552463e+12 0.26938172
# УСЛУГИ-2014               6.796054e+11 9.165579e+11 1.958038e+12 0.09253419
# УСЛУГИ-2015               8.141875e+11 1.078276e+12 2.229128e+12 0.11561862
# УСЛУГИ-2016               9.371955e+11 1.202133e+12 2.405382e+12 0.12545104
# УСЛУГИ-2017               9.233422e+11 1.205748e+12 2.434462e+12 0.10654605
# ФИНАНСОВЫЕ ИНСТИТУТЫ-2013 2.424759e+13 2.470067e+13 2.490535e+13 0.87993654
# ФИНАНСОВЫЕ ИНСТИТУТЫ-2014 1.973303e+13 2.016691e+13 2.036067e+13 0.82256079
# ФИНАНСОВЫЕ ИНСТИТУТЫ-2015 2.495574e+13 2.547302e+13 2.571316e+13 0.87477510
# ФИНАНСОВЫЕ ИНСТИТУТЫ-2016 3.341347e+13 3.385043e+13 3.406675e+13 0.87782238
# ФИНАНСОВЫЕ ИНСТИТУТЫ-2017 4.898017e+13 4.942174e+13 4.963803e+13 0.92172334
# ЭЛЕКТРОЭНЕРГЕТИКА-2013    3.265575e+12 3.986748e+12 4.175826e+12 0.31151396
# ЭЛЕКТРОЭНЕРГЕТИКА-2014    3.436081e+12 4.254582e+12 4.471688e+12 0.30201464
# ЭЛЕКТРОЭНЕРГЕТИКА-2015    3.748740e+12 4.619413e+12 4.853140e+12 0.30651822
# ЭЛЕКТРОЭНЕРГЕТИКА-2016    4.128330e+12 5.078440e+12 5.343419e+12 0.31272436
# ЭЛЕКТРОЭНЕРГЕТИКА-2017    4.531861e+12 5.541880e+12 5.834867e+12 0.31665661
#                           CR.50.    CR.100.   ⋯ real_prices real_gdp_change
# IT-2013                   0.4164684 0.5233982 ⋯  34351.5108  1289.1494
# IT-2014                   0.4177851 0.5219299 ⋯  48277.4094   408.8907
# IT-2015                   0.4331771 0.5383738 ⋯  94522.4299 -1971.4729
# IT-2016                   0.4663022 0.5637347 ⋯ 257624.4652   497.0722
# IT-2017                   0.2083735 0.2993937 ⋯  36759.1762  1216.0974
# ДОБЫЧА-2013               0.8263441 0.9002218 ⋯  16702.8706  1289.1494
# ДОБЫЧА-2014               0.8270596 0.9019827 ⋯   8217.7090   408.8907
# ДОБЫЧА-2015               0.8105689 0.8905463 ⋯   5716.0842 -1971.4729
# ДОБЫЧА-2016               0.7987361 0.8838686 ⋯  27747.2148   497.0722
# ДОБЫЧА-2017               0.7972771 0.8828249 ⋯   7018.8318  1216.0974
# ЛЕГКАЯ-2013               0.4976503 0.6076919 ⋯    208.0077  1289.1494
# ЛЕГКАЯ-2014               0.5034007 0.6135846 ⋯    246.8350   408.8907
# ЛЕГКАЯ-2015               0.4836190 0.6017147 ⋯    427.9025 -1971.4729
# ЛЕГКАЯ-2016               0.4989521 0.6126264 ⋯      0.0000   497.0722
# ЛЕГКАЯ-2017               0.5119036 0.6299652 ⋯    119.8606  1216.0974
# ЛЕСНАЯ-2013               0.5146105 0.6616123 ⋯   4289.8623  1289.1494
# ЛЕСНАЯ-2014               0.4996358 0.6498668 ⋯  28212.4431   408.8907
# ЛЕСНАЯ-2015               0.5088824 0.6552958 ⋯    868.1134 -1971.4729
# ЛЕСНАЯ-2016               0.5351169 0.6782475 ⋯   7350.7364   497.0722
# ЛЕСНАЯ-2017               0.5453667 0.6834908 ⋯   1127.7579  1216.0974
# МАШИНОСТРОЕНИЕ-2013       0.5419719 0.6499937 ⋯  30922.2300  1289.1494
# МАШИНОСТРОЕНИЕ-2014       0.5342111 0.6449060 ⋯  45330.9255   408.8907
# МАШИНОСТРОЕНИЕ-2015       0.5101334 0.6188811 ⋯  11351.6202 -1971.4729
# МАШИНОСТРОЕНИЕ-2016       0.5173456 0.6241934 ⋯  16049.7056   497.0722
# МАШИНОСТРОЕНИЕ-2017       0.5307097 0.6385205 ⋯   5752.2479  1216.0974
# МЕТАЛЛУРГИЯ-2013          0.8601691 0.9467736 ⋯  41850.3187  1289.1494
# МЕТАЛЛУРГИЯ-2014          0.8648694 0.9467636 ⋯  30924.7588   408.8907
# МЕТАЛЛУРГИЯ-2015          0.8613303 0.9464056 ⋯  35876.4732 -1971.4729
# МЕТАЛЛУРГИЯ-2016          0.8547078 0.9432325 ⋯  18210.2910   497.0722
# МЕТАЛЛУРГИЯ-2017          0.8537977 0.9437020 ⋯  10975.3727  1216.0974
# ⋮                         ⋮         ⋮         ⋱ ⋮           ⋮
# СТРОИТЕЛЬСТВО-2013        0.3268828 0.4198170 ⋯  132014.39   1289.1494
# СТРОИТЕЛЬСТВО-2014        0.3187196 0.4030636 ⋯  154811.10    408.8907
# СТРОИТЕЛЬСТВО-2015        0.3167483 0.4040596 ⋯  506462.23  -1971.4729
# СТРОИТЕЛЬСТВО-2016        0.3292662 0.4051603 ⋯  531679.43    497.0722
# СТРОИТЕЛЬСТВО-2017        0.3275940 0.4052837 ⋯  164371.24   1216.0974
# ТОРГОВЛЯ-2013             0.4103316 0.4869552 ⋯  101930.62   1289.1494
# ТОРГОВЛЯ-2014             0.4066444 0.4834773 ⋯   60052.63    408.8907
# ТОРГОВЛЯ-2015             0.4091503 0.4818928 ⋯   85477.18  -1971.4729
# ТОРГОВЛЯ-2016             0.4003913 0.4707777 ⋯  149289.51    497.0722
# ТОРГОВЛЯ-2017             0.3944027 0.4681105 ⋯   75886.57   1216.0974
# ТЭК-2013                  0.6987610 0.8149195 ⋯ 2229095.58   1289.1494
# ТЭК-2014                  0.7003736 0.8114664 ⋯  584795.15    408.8907
# ТЭК-2015                  0.6906566 0.8039568 ⋯  411375.13  -1971.4729
# ТЭК-2016                  0.6708706 0.7933022 ⋯   37407.84    497.0722
# ТЭК-2017                  0.6804599 0.7975218 ⋯  643243.05   1216.0974
# УСЛУГИ-2013               0.3708613 0.4320738 ⋯   69472.05   1289.1494
# УСЛУГИ-2014               0.2108390 0.2843505 ⋯   72418.61    408.8907
# УСЛУГИ-2015               0.2258200 0.2990665 ⋯   47288.50  -1971.4729
# УСЛУГИ-2016               0.2413274 0.3095487 ⋯   44933.17    497.0722
# УСЛУГИ-2017               0.2288757 0.2988776 ⋯   67900.81   1216.0974
# ФИНАНСОВЫЕ ИНСТИТУТЫ-2013 0.9609560 0.9789122 ⋯  103958.52   1289.1494
# ФИНАНСОВЫЕ ИНСТИТУТЫ-2014 0.9521942 0.9731304 ⋯  117561.11    408.8907
# ФИНАНСОВЫЕ ИНСТИТУТЫ-2015 0.9563297 0.9761524 ⋯  129780.46  -1971.4729
# ФИНАНСОВЫЕ ИНСТИТУТЫ-2016 0.9700340 0.9827196 ⋯   56594.21    497.0722
# ФИНАНСОВЫЕ ИНСТИТУТЫ-2017 0.9795232 0.9883539 ⋯  403073.13   1216.0974
# ЭЛЕКТРОЭНЕРГЕТИКА-2013    0.6868261 0.8385055 ⋯  117993.85   1289.1494
# ЭЛЕКТРОЭНЕРГЕТИКА-2014    0.6687179 0.8280118 ⋯   26360.65    408.8907
# ЭЛЕКТРОЭНЕРГЕТИКА-2015    0.6746843 0.8313847 ⋯   14301.95  -1971.4729
# ЭЛЕКТРОЭНЕРГЕТИКА-2016    0.6755832 0.8310646 ⋯   24413.60    497.0722
# ЭЛЕКТРОЭНЕРГЕТИКА-2017    0.6805555 0.8322314 ⋯   22130.74   1216.0974
#                           market_type type_1 type_2 type_3 type_4 log_ihh
# IT-2013                   0           0      0      0      0      4.459206
# IT-2014                   0           0      0      0      0      4.514560
# IT-2015                   0           0      0      0      0      4.592295
# IT-2016                   1           1      0      0      0      4.706165
# IT-2017                   0           0      0      0      0      2.633643
# ДОБЫЧА-2013               3           0      0      1      0      6.893536
# ДОБЫЧА-2014               4           0      0      0      1      7.014341
# ДОБЫЧА-2015               3           0      0      1      0      6.736945
# ДОБЫЧА-2016               3           0      0      1      0      6.736603
# ДОБЫЧА-2017               3           0      0      1      0      6.810065
# ЛЕГКАЯ-2013               1           1      0      0      0      5.168451
# ЛЕГКАЯ-2014               1           1      0      0      0      5.288417
# ЛЕГКАЯ-2015               1           1      0      0      0      4.755807
# ЛЕГКАЯ-2016               1           1      0      0      0      4.892431
# ЛЕГКАЯ-2017               1           1      0      0      0      5.024105
# ЛЕСНАЯ-2013               1           1      0      0      0      4.755441
# ЛЕСНАЯ-2014               1           1      0      0      0      4.638413
# ЛЕСНАЯ-2015               1           1      0      0      0      4.638393
# ЛЕСНАЯ-2016               1           1      0      0      0      4.738965
# ЛЕСНАЯ-2017               1           1      0      0      0      4.697215
# МАШИНОСТРОЕНИЕ-2013       1           1      0      0      0      4.783899
# МАШИНОСТРОЕНИЕ-2014       1           1      0      0      0      4.763195
# МАШИНОСТРОЕНИЕ-2015       0           0      0      0      0      4.541992
# МАШИНОСТРОЕНИЕ-2016       0           0      0      0      0      4.568430
# МАШИНОСТРОЕНИЕ-2017       1           1      0      0      0      4.655972
# МЕТАЛЛУРГИЯ-2013          2           0      1      0      0      5.902415
# МЕТАЛЛУРГИЯ-2014          2           0      1      0      0      5.945428
# МЕТАЛЛУРГИЯ-2015          2           0      1      0      0      5.938364
# МЕТАЛЛУРГИЯ-2016          2           0      1      0      0      5.971288
# МЕТАЛЛУРГИЯ-2017          3           0      0      1      0      5.992644
# ⋮                         ⋮           ⋮      ⋮      ⋮      ⋮      ⋮
# СТРОИТЕЛЬСТВО-2013        0           0      0      0      0      3.973494
# СТРОИТЕЛЬСТВО-2014        0           0      0      0      0      3.752980
# СТРОИТЕЛЬСТВО-2015        0           0      0      0      0      3.939772
# СТРОИТЕЛЬСТВО-2016        0           0      0      0      0      3.948039
# СТРОИТЕЛЬСТВО-2017        0           0      0      0      0      4.096054
# ТОРГОВЛЯ-2013             1           1      0      0      0      5.280000
# ТОРГОВЛЯ-2014             1           1      0      0      0      5.099642
# ТОРГОВЛЯ-2015             1           1      0      0      0      5.102231
# ТОРГОВЛЯ-2016             1           1      0      0      0      4.845855
# ТОРГОВЛЯ-2017             1           1      0      0      0      4.855978
# ТЭК-2013                  3           0      0      1      0      6.381562
# ТЭК-2014                  3           0      0      1      0      6.515118
# ТЭК-2015                  3           0      0      1      0      6.251443
# ТЭК-2016                  3           0      0      1      0      6.216896
# ТЭК-2017                  3           0      0      1      0      6.334258
# УСЛУГИ-2013               2           0      1      0      0      5.899691
# УСЛУГИ-2014               0           0      0      0      0      2.810518
# УСЛУГИ-2015               0           0      0      0      0      3.183696
# УСЛУГИ-2016               0           0      0      0      0      3.376817
# УСЛУГИ-2017               0           0      0      0      0      3.062801
# ФИНАНСОВЫЕ ИНСТИТУТЫ-2013 4           0      0      0      1      8.255669
# ФИНАНСОВЫЕ ИНСТИТУТЫ-2014 4           0      0      0      1      7.975309
# ФИНАНСОВЫЕ ИНСТИТУТЫ-2015 4           0      0      0      1      8.221219
# ФИНАНСОВЫЕ ИНСТИТУТЫ-2016 4           0      0      0      1      8.517403
# ФИНАНСОВЫЕ ИНСТИТУТЫ-2017 4           0      0      0      1      8.728961
# ЭЛЕКТРОЭНЕРГЕТИКА-2013    1           1      0      0      0      5.030628
# ЭЛЕКТРОЭНЕРГЕТИКА-2014    1           1      0      0      0      4.988191
# ЭЛЕКТРОЭНЕРГЕТИКА-2015    1           1      0      0      0      4.999965
# ЭЛЕКТРОЭНЕРГЕТИКА-2016    1           1      0      0      0      5.013403
# ЭЛЕКТРОЭНЕРГЕТИКА-2017    1           1      0      0      0      5.053282
#                           log_ma    ma_lag
# IT-2013                   10.444401          NA
# IT-2014                   10.857040  34351.5100
# IT-2015                   11.605874  51898.2100
# IT-2016                   12.636155 109740.5400
# IT-2017                   10.740683 307476.8600
# ДОБЫЧА-2013                9.723336          NA
# ДОБЫЧА-2014                9.086367  16702.8700
# ДОБЫЧА-2015                8.800320   8834.0300
# ДОБЫЧА-2016               10.407788   6636.3700
# ДОБЫЧА-2017                9.084892  33116.5200
# ЛЕГКАЯ-2013                5.337575          NA
# ЛЕГКАЯ-2014                5.581041    208.0077
# ЛЕГКАЯ-2015                6.208177    265.3476
# ЛЕГКАЯ-2016                      NA    496.7948
# ЛЕГКАЯ-2017                5.014869          NA
# ЛЕСНАЯ-2013                8.364010          NA
# ЛЕСНАЯ-2014               10.319839   4289.8623
# ЛЕСНАЯ-2015                6.915604  30328.3764
# ЛЕСНАЯ-2016                9.079453   1007.8796
# ЛЕСНАЯ-2017                7.256527   8773.1627
# МАШИНОСТРОЕНИЕ-2013       10.339231          NA
# МАШИНОСТРОЕНИЕ-2014       10.794065  30922.2300
# МАШИНОСТРОЕНИЕ-2015        9.486397  48730.7449
# МАШИНОСТРОЕНИЕ-2016        9.860343  13179.2311
# МАШИНОСТРОЕНИЕ-2017        8.885886  19155.4520
# МЕТАЛЛУРГИЯ-2013          10.641855          NA
# МЕТАЛЛУРГИЯ-2014          10.411633  41850.3187
# МЕТАЛЛУРГИЯ-2015          10.637119  33244.1157
# МЕТАЛЛУРГИЯ-2016           9.986639  41652.5854
# МЕТАЛЛУРГИЯ-2017           9.531949  21734.1280
# ⋮                         ⋮         ⋮
# СТРОИТЕЛЬСТВО-2013        11.790666         NA
# СТРОИТЕЛЬСТВО-2014        12.022282  132014.39
# СТРОИТЕЛЬСТВО-2015        13.284487  166421.93
# СТРОИТЕЛЬСТВО-2016        13.360693  588002.65
# СТРОИТЕЛЬСТВО-2017        12.238423  634563.66
# ТОРГОВЛЯ-2013             11.532048         NA
# ТОРГОВЛЯ-2014             11.075297  101930.62
# ТОРГОВЛЯ-2015             11.505286   64556.57
# ТОРГОВЛЯ-2016             12.090540   99239.01
# ТОРГОВЛЯ-2017             11.444328  178178.23
# ТЭК-2013                  14.617106         NA
# ТЭК-2014                  13.351338 2229095.58
# ТЭК-2015                  13.076543  628654.78
# ТЭК-2016                  10.706532  477606.53
# ТЭК-2017                  13.602818   44646.55
# УСЛУГИ-2013               11.148680         NA
# УСЛУГИ-2014               11.262539   69472.05
# УСЛУГИ-2015               10.913304   77850.01
# УСЛУГИ-2016               10.889828   54901.95
# УСЛУГИ-2017               11.354343   53628.09
# ФИНАНСОВЫЕ ИНСТИТУТЫ-2013 11.551747         NA
# ФИНАНСОВЫЕ ИНСТИТУТЫ-2014 11.747034  103958.52
# ФИНАНСОВЫЕ ИНСТИТУТЫ-2015 11.922881  126378.19
# ФИНАНСОВЫЕ ИНСТИТУТЫ-2016 11.120559  150675.12
# ФИНАНСОВЫЕ ИНСТИТУТЫ-2017 13.135413   67545.64
# ЭЛЕКТРОЭНЕРГЕТИКА-2013    11.678388         NA
# ЭЛЕКТРОЭНЕРГЕТИКА-2014    10.251948  117993.85
# ЭЛЕКТРОЭНЕРГЕТИКА-2015     9.717433   28337.70
# ЭЛЕКТРОЭНЕРГЕТИКА-2016    10.279793   16604.57
# ЭЛЕКТРОЭНЕРГЕТИКА-2017    10.233263   29137.83

# %%
coplot(CR10. ~ year|otrasl, type="b", data=df_ihh)
# Out:
# plot without title

# %%
library(gplots)

# %%
plotmeans(CR10. ~ year, data = df_ihh)
# plotmeans(CR10. ~ otrasl, data = df_ihh)
# Out:
# plot without title

# %%
ols <-lm(CR10.~log_ma, data = df_ihh)
summary(ols)
# Out:
# Call:
# lm(formula = CR10. ~ log_ma, data = df_ihh)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.29506 -0.08192  0.04258  0.08384  0.17879
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 0.646958   0.076714   8.433 6.48e-13 ***
# log_ma      0.014680   0.007294   2.013   0.0472 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.1181 on 87 degrees of freedom
#   (1 observation deleted due to missingness)
# Multiple R-squared:  0.04449,	Adjusted R-squared:  0.03351
# F-statistic: 4.051 on 1 and 87 DF,  p-value: 0.04723

# %%
library(ggplot2)

# %%
yhat <- ols$fitted
ggplot(df_ihh, aes(x = log(MA), y = CR10.))+
  geom_point() 
# +
#    geom_smooth(method=lm)
# Out:
# Warning message:
# “Removed 1 rows containing missing values (geom_point).”
# plot without title

# %%
fixed.dum <-lm(CR10.~log_ma + factor(otrasl) - 1, data = df_ihh)
summary(fixed.dum)
# Out:
# Call:
# lm(formula = CR10. ~ log_ma + factor(otrasl) - 1, data = df_ihh)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.194394 -0.005103 -0.001052  0.005833  0.066603
#
# Coefficients:
#                                    Estimate Std. Error t value Pr(>|t|)
# log_ma                             0.005344   0.004541   1.177    0.243
# factor(otrasl)IT                   0.646572   0.052849  12.234   <2e-16 ***
# factor(otrasl)ДОБЫЧА               0.877561   0.044833  19.574   <2e-16 ***
# factor(otrasl)ЛЕГКАЯ               0.682806   0.029272  23.326   <2e-16 ***
# factor(otrasl)ЛЕСНАЯ               0.559930   0.040380  13.867   <2e-16 ***
# factor(otrasl)МАШИНОСТРОЕНИЕ       0.805345   0.046799  17.209   <2e-16 ***
# factor(otrasl)МЕТАЛЛУРГИЯ          0.816365   0.048405  16.865   <2e-16 ***
# factor(otrasl)НЕФТЕХИМ             0.855761   0.050305  17.011   <2e-16 ***
# factor(otrasl)ПИЩЕВАЯ              0.719563   0.047424  15.173   <2e-16 ***
# factor(otrasl)СВЯЗЬ                0.897480   0.048181  18.627   <2e-16 ***
# factor(otrasl)СЕЛЬХОЗ              0.578708   0.051112  11.322   <2e-16 ***
# factor(otrasl)СМИ                  0.798517   0.046756  17.078   <2e-16 ***
# factor(otrasl)СПОРТ                0.658202   0.042642  15.436   <2e-16 ***
# factor(otrasl)СТРОИТЕЛЬСТВО        0.650077   0.058500  11.112   <2e-16 ***
# factor(otrasl)ТОРГОВЛЯ             0.690576   0.054047  12.777   <2e-16 ***
# factor(otrasl)ТЭК                  0.827569   0.060852  13.600   <2e-16 ***
# factor(otrasl)УСЛУГИ               0.569445   0.052220  10.905   <2e-16 ***
# factor(otrasl)ФИНАНСОВЫЕ ИНСТИТУТЫ 0.923740   0.055659  16.596   <2e-16 ***
# factor(otrasl)ЭЛЕКТРОЭНЕРГЕТИКА    0.818781   0.049236  16.630   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.03 on 70 degrees of freedom
#   (1 observation deleted due to missingness)
# Multiple R-squared:  0.9989,	Adjusted R-squared:  0.9986
# F-statistic:  3395 on 19 and 70 DF,  p-value: < 2.2e-16

# %%
library(car)

# %%
# yhat <- fixed.dum$fitted
# scatterplot(yhat ~ df_ihh$log_ma | df_ihh$otrasl,  xlab ="x1", ylab ="yhat", boxplots = FALSE,smooth = FALSE)
# abline(lm(df_ihh$CR10.~df_ihh$log_ma),lwd=3, col="red")

# %%
fixed <- plm(CR10.~log_ma, data = df_ihh, model="within")
summary(fixed)
# Out:
# Oneway (individual) effect Within Model
#
# Call:
# plm(formula = CR10. ~ log_ma, data = df_ihh, model = "within")
#
# Unbalanced Panel: n = 18, T = 4-5, N = 89
#
# Residuals:
#       Min.    1st Qu.     Median    3rd Qu.       Max.
# -0.1943942 -0.0051032 -0.0010520  0.0058335  0.0666025
#
# Coefficients:
#         Estimate Std. Error t-value Pr(>|t|)
# log_ma 0.0053438  0.0045410  1.1768   0.2433
#
# Total Sum of Squares:    0.064255
# Residual Sum of Squares: 0.063009
# R-Squared:      0.0194
# Adj. R-Squared: -0.23275
# F-statistic: 1.38487 on 1 and 70 DF, p-value: 0.24326

# %%
fixef(fixed)
# Out:
#                   IT               ДОБЫЧА               ЛЕГКАЯ
#            0.6465722            0.8775613            0.6828061
#               ЛЕСНАЯ       МАШИНОСТРОЕНИЕ          МЕТАЛЛУРГИЯ
#            0.5599299            0.8053448            0.8163653
#             НЕФТЕХИМ              ПИЩЕВАЯ                СВЯЗЬ
#            0.8557614            0.7195629            0.8974796
#              СЕЛЬХОЗ                  СМИ                СПОРТ
#            0.5787084            0.7985166            0.6582024
#        СТРОИТЕЛЬСТВО             ТОРГОВЛЯ                  ТЭК
#            0.6500774            0.6905763            0.8275688
#               УСЛУГИ ФИНАНСОВЫЕ ИНСТИТУТЫ    ЭЛЕКТРОЭНЕРГЕТИКА
#            0.5694452            0.9237397            0.8187810

# %%
pFtest(fixed, ols)
# Out:
# 	F test for individual effects
#
# data:  CR10. ~ log_ma
# F = 75.142, df1 = 17, df2 = 70, p-value < 2.2e-16
# alternative hypothesis: significant effects

# %% [markdown]
# p-value < 0.05 выбираем fe model

# %%
random <- plm(CR10.~log_ma, data = df_ihh, model="random")
summary(random)
# Out:
# Oneway (individual) effect Random Effect Model
#    (Swamy-Arora's transformation)
#
# Call:
# plm(formula = CR10. ~ log_ma, data = df_ihh, model = "random")
#
# Unbalanced Panel: n = 18, T = 4-5, N = 89
#
# Effects:
#                     var   std.dev share
# idiosyncratic 0.0009001 0.0300020 0.059
# individual    0.0142292 0.1192862 0.941
# theta:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#  0.8752  0.8882  0.8882  0.8876  0.8882  0.8882
#
# Residuals:
#      Min.   1st Qu.    Median      Mean   3rd Qu.      Max.
# -0.204891 -0.011443  0.006520  0.000037  0.014652  0.048036
#
# Coefficients:
#              Estimate Std. Error z-value Pr(>|z|)
# (Intercept) 0.7356190  0.0532311  13.819   <2e-16 ***
# log_ma      0.0060759  0.0043742   1.389   0.1648
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Total Sum of Squares:    0.078919
# Residual Sum of Squares: 0.07768
# R-Squared:      0.016305
# Adj. R-Squared: 0.0049985
# Chisq: 1.38742 on 1 DF, p-value: 0.23884

# %%
phtest(fixed, random)
# Out:
# 	Hausman Test
#
# data:  CR10. ~ log_ma
# chisq = 0.3604, df = 1, p-value = 0.5483
# alternative hypothesis: one model is inconsistent

# %% [markdown]
# p-value > 0.5 используем  RE модель

# %%
fixed.time <- plm(CR10.~log_ma + factor(year), data=df_ihh, model="within")
summary(fixed.time)
# Out:
# Oneway (individual) effect Within Model
#
# Call:
# plm(formula = CR10. ~ log_ma + factor(year), data = df_ihh, model = "within")
#
# Unbalanced Panel: n = 18, T = 4-5, N = 89
#
# Residuals:
#        Min.     1st Qu.      Median     3rd Qu.        Max.
# -0.18579906 -0.00641624 -0.00066098  0.00685090  0.06176810
#
# Coefficients:
#                    Estimate Std. Error t-value Pr(>|t|)
# log_ma            0.0046361  0.0046416  0.9988   0.3215
# factor(year)2014 -0.0053573  0.0101322 -0.5287   0.5988
# factor(year)2015 -0.0032521  0.0101311 -0.3210   0.7492
# factor(year)2016 -0.0018668  0.0103397 -0.1805   0.8573
# factor(year)2017 -0.0138196  0.0101515 -1.3613   0.1780
#
# Total Sum of Squares:    0.064255
# Residual Sum of Squares: 0.060959
# R-Squared:      0.051293
# Adj. R-Squared: -0.26494
# F-statistic: 0.713674 on 5 and 66 DF, p-value: 0.61535

# %%
pFtest(fixed.time, fixed)
# Out:
# 	F test for individual effects
#
# data:  CR10. ~ log_ma + factor(year)
# F = 0.55469, df1 = 4, df2 = 66, p-value = 0.6963
# alternative hypothesis: significant effects

# %%
plmtest(fixed, c("time"), type=("bp"))
# Out:
# 	Lagrange Multiplier Test - time effects (Breusch-Pagan) for unbalanced
# 	panels
#
# data:  CR10. ~ log_ma
# chisq = 2.5243, df = 1, p-value = 0.1121
# alternative hypothesis: significant effects

# %% [markdown]
# нет фиксированных временных эффектов

# %%
pool <- plm(CR10.~log_ma, data = df_ihh, model="pooling")
summary(pool)
# Out:
# Pooling Model
#
# Call:
# plm(formula = CR10. ~ log_ma, data = df_ihh, model = "pooling")
#
# Unbalanced Panel: n = 18, T = 4-5, N = 89
#
# Residuals:
#      Min.   1st Qu.    Median   3rd Qu.      Max.
# -0.295062 -0.081917  0.042580  0.083835  0.178786
#
# Coefficients:
#              Estimate Std. Error t-value  Pr(>|t|)
# (Intercept) 0.6469584  0.0767142  8.4334 6.481e-13 ***
# log_ma      0.0146805  0.0072937  2.0128   0.04723 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Total Sum of Squares:    1.2693
# Residual Sum of Squares: 1.2128
# R-Squared:      0.044494
# Adj. R-Squared: 0.033511
# F-statistic: 4.05126 on 1 and 87 DF, p-value: 0.04723

# %%
plmtest(pool, type=c("bp"))
# Out:
# 	Lagrange Multiplier Test - (Breusch-Pagan) for unbalanced panels
#
# data:  CR10. ~ log_ma
# chisq = 156.01, df = 1, p-value < 2.2e-16
# alternative hypothesis: significant effects

# %% [markdown]
# p-value < 2.2e-16  используем re модель

# %%
pcdtest(fixed, test = c("lm"))
# Out:
# 	Breusch-Pagan LM test for cross-sectional dependence in panels
#
# data:  CR10. ~ log_ma
# chisq = 218.63, df = 153, p-value = 0.0003954
# alternative hypothesis: cross-sectional dependence

# %%
pcdtest(fixed, test = c("cd"))
# Out:
# 	Pesaran CD test for cross-sectional dependence in panels
#
# data:  CR10. ~ log_ma
# z = -1.1228, p-value = 0.2615
# alternative hypothesis: cross-sectional dependence

# %% [markdown]
# p-value > 0.05 нет кросс-секциональной зависимости

# %%
pbgtest(fixed)
# Out:
# 	Breusch-Godfrey/Wooldridge test for serial correlation in panel models
#
# data:  CR10. ~ log_ma
# chisq = 7.4692, df = 4, p-value = 0.1131
# alternative hypothesis: serial correlation in idiosyncratic errors

# %% [markdown]
# Есть серийная корреляция, однако на коротких временных рядах - это не является проблемой

# %%
library(tseries)

# %%
adf.test(df_ihh$CR10., k=2)
# Out:
# Warning message in adf.test(df_ihh$CR10., k = 2):
# “p-value smaller than printed p-value”
# 	Augmented Dickey-Fuller Test
#
# data:  df_ihh$CR10.
# Dickey-Fuller = -4.1456, Lag order = 2, p-value = 0.01
# alternative hypothesis: stationary

# %% [markdown]
# p-value < 0.05 ряды не имеют единичного корня

# %%
library(lmtest)
# Out:
# Loading required package: zoo
#
# Attaching package: ‘zoo’
#
# The following objects are masked from ‘package:base’:
#
#     as.Date, as.Date.numeric

# %%
bptest(CR10.~log_ma, data = df_ihh, studentize=F)
# Out:
# 	Breusch-Pagan test
#
# data:  CR10. ~ log_ma
# BP = 0.45606, df = 1, p-value = 0.4995

# %% [markdown]
# НЕТ гетероскдастичности

# %%
coeftest(random)
# Out:
# t test of coefficients:
#
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 0.7356190  0.0532311  13.819   <2e-16 ***
# log_ma      0.0060759  0.0043742   1.389   0.1684
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
coeftest(random, vcovHC)
# Out:
# t test of coefficients:
#
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 0.7356190  0.0498785 14.7482   <2e-16 ***
# log_ma      0.0060759  0.0037699  1.6117   0.1106
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
coeftest(random, vcovHC(random, type = "HC3"))
# Out:
# t test of coefficients:
#
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 0.7356190  0.0512604  14.351   <2e-16 ***
# log_ma      0.0060759  0.0039250   1.548   0.1252
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %% [markdown]
# HC3 – Recommended for small samples. HC3 gives less weight to influential observations.

# %%
random <- plm(CR10.~log_ma+log(ma_lag), data = df_ihh, model="random")
summary(random)
# Out:
# Oneway (individual) effect Random Effect Model
#    (Swamy-Arora's transformation)
#
# Call:
# plm(formula = CR10. ~ log_ma + log(ma_lag), data = df_ihh, model = "random")
#
# Unbalanced Panel: n = 18, T = 2-4, N = 70
#
# Effects:
#                     var   std.dev share
# idiosyncratic 0.0009592 0.0309712 0.059
# individual    0.0151631 0.1231385 0.941
# theta:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#  0.8249  0.8752  0.8752  0.8738  0.8752  0.8752
#
# Residuals:
#      Min.   1st Qu.    Median      Mean   3rd Qu.      Max.
# -0.189288 -0.013043  0.004822  0.000173  0.017796  0.058402
#
# Coefficients:
#               Estimate Std. Error z-value Pr(>|z|)
# (Intercept)  0.7842139  0.0873055  8.9824   <2e-16 ***
# log_ma       0.0061580  0.0052755  1.1673   0.2431
# log(ma_lag) -0.0049309  0.0051086 -0.9652   0.3344
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Total Sum of Squares:    0.066609
# Residual Sum of Squares: 0.063391
# R-Squared:      0.052262
# Adj. R-Squared: 0.023972
# Chisq: 3.4011 on 2 DF, p-value: 0.18258

# %%
coeftest(random, vcovHC)
# Out:
# t test of coefficients:
#
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.7842139  0.0554613 14.1398   <2e-16 ***
# log_ma       0.0061580  0.0048433  1.2715   0.2080
# log(ma_lag) -0.0049309  0.0077561 -0.6358   0.5271
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
coeftest(random, vcovHC(random, type = "HC3"))
# Out:
# t test of coefficients:
#
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.7842139  0.0595526 13.1684   <2e-16 ***
# log_ma       0.0061580  0.0052119  1.1815   0.2416
# log(ma_lag) -0.0049309  0.0083385 -0.5913   0.5563
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
random <- plm(CR10.~log_ma+log(ma_lag)+real_prices+real_gdp_change, data = df_ihh, model="random")
summary(random)
# Out:
# Oneway (individual) effect Random Effect Model
#    (Swamy-Arora's transformation)
#
# Call:
# plm(formula = CR10. ~ log_ma + log(ma_lag) + real_prices + real_gdp_change,
#     data = df_ihh, model = "random")
#
# Unbalanced Panel: n = 18, T = 2-4, N = 70
#
# Effects:
#                     var   std.dev share
# idiosyncratic 0.0009793 0.0312933 0.054
# individual    0.0171318 0.1308884 0.946
# theta:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#  0.8333  0.8813  0.8813  0.8799  0.8813  0.8813
#
# Residuals:
#      Min.   1st Qu.    Median      Mean   3rd Qu.      Max.
# -0.184923 -0.011715  0.004519  0.000185  0.016997  0.058961
#
# Coefficients:
#                    Estimate  Std. Error z-value Pr(>|z|)
# (Intercept)      8.0733e-01  9.7832e-02  8.2523   <2e-16 ***
# log_ma           3.8509e-03  6.8147e-03  0.5651   0.5720
# log(ma_lag)     -5.0845e-03  5.1258e-03 -0.9919   0.3212
# real_prices      2.8258e-08  5.6922e-08  0.4964   0.6196
# real_gdp_change -2.4757e-06  3.0528e-06 -0.8109   0.4174
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Total Sum of Squares:    0.065104
# Residual Sum of Squares: 0.061106
# R-Squared:      0.065083
# Adj. R-Squared: 0.0075491
# Chisq: 4.25227 on 4 DF, p-value: 0.37294

# %%
coeftest(random, vcovHC)
# Out:
# t test of coefficients:
#
#                    Estimate  Std. Error t value Pr(>|t|)
# (Intercept)      8.0733e-01  7.0626e-02 11.4311   <2e-16 ***
# log_ma           3.8509e-03  4.0525e-03  0.9502   0.3455
# log(ma_lag)     -5.0845e-03  7.6053e-03 -0.6685   0.5062
# real_prices      2.8258e-08  3.9861e-08  0.7089   0.4809
# real_gdp_change -2.4757e-06  2.6135e-06 -0.9473   0.3470
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
coeftest(random, vcovHC(random, type = "HC3"))
# Out:
# t test of coefficients:
#
#                    Estimate  Std. Error t value  Pr(>|t|)
# (Intercept)      8.0733e-01  7.7595e-02 10.4045 1.798e-15 ***
# log_ma           3.8509e-03  4.4195e-03  0.8713    0.3868
# log(ma_lag)     -5.0845e-03  8.3723e-03 -0.6073    0.5458
# real_prices      2.8258e-08  4.6743e-08  0.6045    0.5476
# real_gdp_change -2.4757e-06  2.8477e-06 -0.8694    0.3878
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
colnames(df_ihh)
# Out:
#  [1] "year"            "otrasl"          "TR"              "TR10"
#  [5] "TR50"            "TR100"           "TR10."           "CR.10."
#  [9] "CR.50."          "CR.100."         "CR10."           "IHH"
# [13] "MA"              "real_prices"     "real_gdp_change" "market_type"
# [17] "type_1"          "type_2"          "type_3"          "type_4"
# [21] "log_ihh"         "log_ma"          "ma_lag"

# %%
random <- plm(CR10.~log_ma+log(ma_lag)+real_prices+real_gdp_change+market_type, data = df_ihh, model="random")
summary(random)
# Out:
# Oneway (individual) effect Random Effect Model
#    (Swamy-Arora's transformation)
#
# Call:
# plm(formula = CR10. ~ log_ma + log(ma_lag) + real_prices + real_gdp_change +
#     market_type, data = df_ihh, model = "random")
#
# Unbalanced Panel: n = 18, T = 2-4, N = 70
#
# Effects:
#                     var   std.dev share
# idiosyncratic 0.0009384 0.0306334 0.156
# individual    0.0050765 0.0712497 0.844
# theta:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#  0.7091  0.7898  0.7898  0.7875  0.7898  0.7898
#
# Residuals:
#      Min.   1st Qu.    Median      Mean   3rd Qu.      Max.
# -0.166370 -0.011371  0.004927  0.000157  0.015578  0.058156
#
# Coefficients:
#                    Estimate  Std. Error z-value  Pr(>|z|)
# (Intercept)      6.7496e-01  8.5907e-02  7.8569 3.938e-15 ***
# log_ma           6.9654e-03  6.4558e-03  1.0789    0.2806
# log(ma_lag)     -3.2989e-03  4.8413e-03 -0.6814    0.4956
# real_prices     -4.7664e-09  5.7157e-08 -0.0834    0.9335
# real_gdp_change -4.3787e-06  3.1626e-06 -1.3845    0.1662
# market_type      5.5755e-02  1.0731e-02  5.1954 2.042e-07 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Total Sum of Squares:    0.095425
# Residual Sum of Squares: 0.063689
# R-Squared:      0.33361
# Adj. R-Squared: 0.28155
# Chisq: 31.8908 on 5 DF, p-value: 6.2444e-06

# %%
coeftest(random, vcovHC)
# Out:
# t test of coefficients:
#
#                    Estimate  Std. Error t value  Pr(>|t|)
# (Intercept)      6.7496e-01  6.6915e-02 10.0868 7.497e-15 ***
# log_ma           6.9654e-03  3.5000e-03  1.9901   0.05085 .
# log(ma_lag)     -3.2989e-03  7.3676e-03 -0.4478   0.65584
# real_prices     -4.7664e-09  2.3120e-08 -0.2062   0.83732
# real_gdp_change -4.3787e-06  2.9941e-06 -1.4624   0.14851
# market_type      5.5755e-02  1.1083e-02  5.0308 4.215e-06 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
coeftest(random, vcovHC(random, type = "HC3"))
# Out:
# t test of coefficients:
#
#                    Estimate  Std. Error t value  Pr(>|t|)
# (Intercept)      6.7496e-01  7.4697e-02  9.0360 4.894e-13 ***
# log_ma           6.9654e-03  3.7246e-03  1.8701   0.06604 .
# log(ma_lag)     -3.2989e-03  8.2877e-03 -0.3980   0.69192
# real_prices     -4.7664e-09  2.6283e-08 -0.1813   0.85667
# real_gdp_change -4.3787e-06  3.3950e-06 -1.2898   0.20177
# market_type      5.5755e-02  1.2523e-02  4.4520 3.480e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
random <- plm(CR10.~log_ma+log(ma_lag)+log(real_prices)+real_gdp_change+market_type, data = df_ihh, model="random")
summary(random)
# Out:
# Oneway (individual) effect Random Effect Model
#    (Swamy-Arora's transformation)
#
# Call:
# plm(formula = CR10. ~ log_ma + log(ma_lag) + log(real_prices) +
#     real_gdp_change + market_type, data = df_ihh, model = "random")
#
# Unbalanced Panel: n = 18, T = 2-4, N = 70
#
# Effects:
#                     var   std.dev share
# idiosyncratic 0.0009341 0.0305628 0.142
# individual    0.0056321 0.0750470 0.858
# theta:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#  0.7233  0.8005  0.8005  0.7983  0.8005  0.8005
#
# Residuals:
#      Min.   1st Qu.    Median      Mean   3rd Qu.      Max.
# -0.164724 -0.012540  0.005354  0.000157  0.015096  0.057698
#
# Coefficients:
#                     Estimate  Std. Error z-value  Pr(>|z|)
# (Intercept)       6.8013e-01  7.6916e-02  8.8426 < 2.2e-16 ***
# log_ma            5.5824e-04  1.0334e-02  0.0540    0.9569
# log(ma_lag)      -3.6497e-03  4.8136e-03 -0.7582    0.4483
# log(real_prices)  6.4359e-03  9.8738e-03  0.6518    0.5145
# real_gdp_change  -4.7155e-06  3.1607e-06 -1.4919    0.1357
# market_type       5.4876e-02  1.0869e-02  5.0489 4.444e-07 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Total Sum of Squares:    0.091066
# Residual Sum of Squares: 0.06159
# R-Squared:      0.32474
# Adj. R-Squared: 0.27198
# Chisq: 30.6303 on 5 DF, p-value: 1.1081e-05

# %%
coeftest(random, vcovHC)
# Out:
# t test of coefficients:
#
#                     Estimate  Std. Error t value  Pr(>|t|)
# (Intercept)       6.8013e-01  6.1909e-02 10.9860 2.278e-16 ***
# log_ma            5.5824e-04  2.9251e-03  0.1908    0.8493
# log(ma_lag)      -3.6497e-03  7.4338e-03 -0.4910    0.6251
# log(real_prices)  6.4359e-03  5.2911e-03  1.2164    0.2283
# real_gdp_change  -4.7155e-06  3.2429e-06 -1.4541    0.1508
# market_type       5.4876e-02  1.1378e-02  4.8230 9.103e-06 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
coeftest(random, vcovHC(random, type = "HC3"))
# Out:
# t test of coefficients:
#
#                     Estimate  Std. Error t value  Pr(>|t|)
# (Intercept)       6.8013e-01  7.2840e-02  9.3374 1.463e-13 ***
# log_ma            5.5824e-04  7.5644e-03  0.0738    0.9414
# log(ma_lag)      -3.6497e-03  8.5648e-03 -0.4261    0.6714
# log(real_prices)  6.4359e-03  8.5803e-03  0.7501    0.4560
# real_gdp_change  -4.7155e-06  3.6762e-06 -1.2827    0.2042
# market_type       5.4876e-02  1.2972e-02  4.2304 7.581e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
colnames(df_ihh)
# Out:
#  [1] "year"            "otrasl"          "TR"              "TR10"
#  [5] "TR50"            "TR100"           "TR10."           "CR.10."
#  [9] "CR.50."          "CR.100."         "CR10."           "IHH"
# [13] "MA"              "real_prices"     "real_gdp_change" "market_type"
# [17] "type_1"          "type_2"          "type_3"          "type_4"
# [21] "log_ihh"         "log_ma"          "ma_lag"

# %%
random <- plm(CR10.~log_ma+log(ma_lag)+real_prices+real_gdp_change+type_1+type_2+type_3+type_4, data = df_ihh, model="random")
summary(random)
# Out:
# Oneway (individual) effect Random Effect Model
#    (Swamy-Arora's transformation)
#
# Call:
# plm(formula = CR10. ~ log_ma + log(ma_lag) + real_prices + real_gdp_change +
#     type_1 + type_2 + type_3 + type_4, data = df_ihh, model = "random")
#
# Unbalanced Panel: n = 18, T = 2-4, N = 70
#
# Effects:
#                     var   std.dev share
# idiosyncratic 0.0009596 0.0309767  0.13
# individual    0.0064444 0.0802770  0.87
# theta:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#  0.7368  0.8106  0.8106  0.8084  0.8106  0.8106
#
# Residuals:
#      Min.   1st Qu.    Median      Mean   3rd Qu.      Max.
# -0.163745 -0.010266  0.002392  0.000115  0.013925  0.060099
#
# Coefficients:
#                    Estimate  Std. Error z-value  Pr(>|z|)
# (Intercept)      6.8214e-01  8.7893e-02  7.7610 8.427e-15 ***
# log_ma           5.4749e-03  6.4632e-03  0.8471 0.3969494
# log(ma_lag)     -3.9162e-03  4.8437e-03 -0.8085 0.4187953
# real_prices      4.5994e-09  5.6597e-08  0.0813 0.9352306
# real_gdp_change -3.8800e-06  3.1202e-06 -1.2435 0.2136762
# type_1           5.1432e-02  2.1991e-02  2.3388 0.0193483 *
# type_2           1.6826e-01  4.3782e-02  3.8430 0.0001215 ***
# type_3           1.9208e-01  4.4131e-02  4.3525 1.346e-05 ***
# type_4           2.2612e-01  4.7499e-02  4.7606 1.930e-06 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Total Sum of Squares:    0.087134
# Residual Sum of Squares: 0.057988
# R-Squared:      0.33506
# Adj. R-Squared: 0.24785
# Chisq: 30.6593 on 8 DF, p-value: 0.00016153

# %%
coeftest(random, vcovHC)
# Out:
# t test of coefficients:
#
#                    Estimate  Std. Error t value  Pr(>|t|)
# (Intercept)      6.8214e-01  6.8372e-02  9.9769 1.948e-14 ***
# log_ma           5.4749e-03  3.5855e-03  1.5270 0.1319380
# log(ma_lag)     -3.9162e-03  7.2492e-03 -0.5402 0.5910122
# real_prices      4.5994e-09  2.4617e-08  0.1868 0.8524061
# real_gdp_change -3.8800e-06  3.1441e-06 -1.2341 0.2219137
# type_1           5.1432e-02  2.5992e-02  1.9787 0.0523647 .
# type_2           1.6826e-01  4.3541e-02  3.8643 0.0002725 ***
# type_3           1.9208e-01  3.9477e-02  4.8657 8.394e-06 ***
# type_4           2.2612e-01  3.9300e-02  5.7538 3.017e-07 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
coeftest(random, vcovHC(random, type = "HC3"))
# Out:
# t test of coefficients:
#
#                    Estimate  Std. Error t value  Pr(>|t|)
# (Intercept)      6.8214e-01  7.6951e-02  8.8646 1.454e-12 ***
# log_ma           5.4749e-03  4.0430e-03  1.3541 0.1806859
# log(ma_lag)     -3.9162e-03  8.2230e-03 -0.4762 0.6356009
# real_prices      4.5994e-09  2.9058e-08  0.1583 0.8747578
# real_gdp_change -3.8800e-06  3.6640e-06 -1.0590 0.2937941
# type_1           5.1432e-02  3.3508e-02  1.5349 0.1299680
# type_2           1.6826e-01  5.1030e-02  3.2972 0.0016317 **
# type_3           1.9208e-01  4.9426e-02  3.8863 0.0002535 ***
# type_4           2.2612e-01  4.9017e-02  4.6132 2.084e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %% [markdown]
# Кратко:
#
# a = '4'
# raw.loc[raw[raw.IHH>=1000].index, 'market_type'] =   a
#
# a = '3'
# raw.loc[raw[(raw.IHH<1000) &  (raw.IHH>=400)].index, 'market_type'] =   a
#
# a = '2'
# raw.loc[raw[(raw.IHH<400) &  (raw.IHH>=200)].index, 'market_type'] =   a
#
# a = '1'
# raw.loc[raw[(raw.IHH<200) &  (raw.IHH>=100)].index, 'market_type'] =   a
#
# a = '0'
# raw.loc[raw[(raw.IHH<100)].index, 'market_type'] =   a
#
# - Для анализа была выбрана RE модель
# - Перемнна market_type - пять значений - и соответсвенно 4 дамми для модели
#     - IHH>=1000
#     - (IHH<1000) &  (IHH>=400)
#     - (IHH<400) &  (IHH>=200)
#     - (IHH<200) &  (IHH>=100)
#     - IHH<100
# - Из-за наличия гетероскедастичности необходимо использовать устойчивые к гетероскедастичности оценки ковариационной матрицы
# - Если мы не применяем устойчивые оценки, для некоторых из моделей коэффициент при MA значимый, инчаче значимым остается только Intercept  и market_type (или дамми для типа рынка)
# - IHH ни от цены сделки, ни от логарифма цены, ни от изменения реального ВВП

# %% [markdown]
# В качестве альтернативы можно попрбоватать проверить завсимость логарифма IHH от логарифа MA (расчеты в следующем файле):
