# %% [markdown]
# - https://cran.r-project.org/web/packages/plm/vignettes/plmPackage.html
# - https://cran.r-project.org/web/packages/plm/vignettes/plmModelComponents.html
# - https://cran.r-project.org/web/packages/plm/vignettes/plmFunction.html
# - https://cran.r-project.org/web/packages/plm/plm.pdf
# - https://journal.r-project.org/archive/2017/RJ-2017-003/RJ-2017-003.pdf
# - https://cran.r-project.org/web/packages/dynpanel/dynpanel.pdf
# - http://www.montana.edu/cstoddard/562/Chapter14studentnotes.pdf
#
# Hierarchical models:
#
# - https://www.casact.org/education/rpm/2009/handouts/guszcza.pdf
# - https://fmwww.bc.edu/EC-C/S2013/823/EC823.S2013.nn07.slides.pdf

# %%
library(gplots)
library(plm)
library(dplyr)
library(ggplot2)
library(car)  
library(tseries)  
library(lmtest)

# %%
df_all  <-  read.csv(file="dataframe.csv", header=TRUE, sep=",")

# %%
df_all['year'][df_all['year'] == 2018, ] = 1 
df_all['year'][df_all['year'] == 2019, ] = 2

# %%
df_all['pok_type'] = paste(df_all[['pok']], df_all[['type']])
df_all['group'] = paste(df_all[['sex']], df_all[['age']])

# %%
list_of_pok  <-  list()
un_pok  <- unique(df_all['pok_type'])  
for (i in 1:dim(un_pok)[1]){
    list_of_pok[[i]]  <-  df_all  %>%  filter(pok_type == un_pok[i,1])    
}

# %% [markdown]
# ### Пример на первом показателе

# %%
df  <-  list_of_pok[[1]]
df = pdata.frame(df, index = c('group','date'))
df['value_lagged'] = lag(df$value, 1)
df['value_diff'] = diff(df$value, 1)
head(df)
# Out:
#                 X  date       pok               type  sex age value   year
# 0 18-2018-01-09 13 2018-01-09  Активные клиенты Total 0   18  5466236 1
# 0 18-2018-01-10 14 2018-01-10  Активные клиенты Total 0   18  5528261 1
# 0 18-2018-01-11 15 2018-01-11  Активные клиенты Total 0   18  5543074 1
# 0 18-2018-01-12 16 2018-01-12  Активные клиенты Total 0   18  5528392 1
# 0 18-2019-01-01 17 2019-01-01  Активные клиенты Total 0   18  5514932 2
# 0 18-2019-01-02 18 2019-01-02  Активные клиенты Total 0   18  5510734 2
#                 age_sq inc pok_type                group value_lagged
# 0 18-2018-01-09 324    0    Активные клиенты Total 0 18       NA
# 0 18-2018-01-10 324    0    Активные клиенты Total 0 18  5466236
# 0 18-2018-01-11 324    0    Активные клиенты Total 0 18  5528261
# 0 18-2018-01-12 324    0    Активные клиенты Total 0 18  5543074
# 0 18-2019-01-01 324    0    Активные клиенты Total 0 18  5528392
# 0 18-2019-01-02 324    0    Активные клиенты Total 0 18  5514932
#                 value_diff
# 0 18-2018-01-09         NA
# 0 18-2018-01-10  62025.063
# 0 18-2018-01-11  14812.864
# 0 18-2018-01-12 -14682.037
# 0 18-2019-01-01 -13460.383
# 0 18-2019-01-02  -4197.402

# %%
ggplot(df, aes(x=age, y=value, color=sex)) +
  geom_point() + 
  geom_smooth(method=lm,  formula = y ~ x) + 
  geom_smooth(method=lm,  formula = y ~ (x>20)&(x<60)) + 
  geom_smooth(method=lm,  formula = y ~ x + I(x^2))
# Out:
# plot without title

# %%
ggplot(df, aes(x=age, y=value, color=sex)) +
  geom_point() + 
  geom_smooth(method=lm,  formula = y ~  poly(x,2), data = filter(df, sex==0))+
  geom_smooth(method=lm,  formula = y ~  poly(x,2), data = filter(df, sex==1))
# Out:
# plot without title

# %%
coplot(value ~ date|group, type="b", data=df)
# Out:
# plot without title

# %%
coplot(value_diff ~ date|group, type="b", data=df)
# Out:
#  Missing rows: 1, 14, 27, 40, 53, 66, 79, 92, 105, 118, 131, 144, 157, 170, 183, 196
# plot without title

# %%
ggplot(df, aes(x=age, y=value_diff, color=sex)) +
  geom_point() + 
  geom_smooth(method=lm)
# Out:
# Warning message:
# “Removed 16 rows containing non-finite values (stat_smooth).”Warning message:
# “Removed 16 rows containing missing values (geom_point).”
# plot without title

# %%
plotmeans(value ~ date, data = df)
# Out:
# plot without title

# %% [markdown]
# #### Модель пула:
#
# $$y_{it} = a + \beta_1 sex_{it} +  \beta_2 age_{it} +  \beta_3 age_{it}^2 + \beta_4 inc_{it}+ \beta_5
# year_{it} + \epsilon_{it}$$

# %% [markdown]
# #### FE-модель:
#
# $$y_{it} = a_i + \beta_1 sex_{it} +  \beta_2 age_{it} +  \beta_3 age_{it}^2 + \beta_4 inc_{it}+ \beta_5
# year_{it} + \epsilon_{it}$$
#
# Within-трансформация   для  оценивания FE-модели:
#
# $$y_{it} - \bar{y}_i = \beta_1 (sex_{it}  - \overline{sex}_i ) +  \beta_2 (age_{it}- \overline{age}_i) +  \beta_3 (age_{it}^2 -   \overline{age^2}_i ) + \beta_4 (inc_{it} -  \overline{inc}_i)+ $$
# $$+\beta_5
# (year_{it} - \overline{year}_i) + \epsilon_{it} - \overline{\epsilon}_i$$
#
# Из-за того, что большинство признаков не изменяются внутри групп во времени FE-модель оценивает только:
#
# $$y_{it} - \bar{y}_i =  \beta_5
# (year_{it} - \overline{year}_i) + \epsilon_{it} - \overline{\epsilon}_i$$

# %% [markdown]
# #### RE-модель:
#
# $$y_{it} = a_i + \beta_0 + \beta_1 sex_{it} +  \beta_2 age_{it} +  \beta_3 age_{it}^2 + \beta_4 inc_{it}+ \beta_5
# year_{it} + \epsilon_{it}$$
#
# Предполагаем, что $a_i$ и $sex_{it}$, ..., $year_{it}$   не коррелированы.

# %% [markdown]
# #### Модель пула

# %%
m_pooled <- plm(value~sex+age+age_sq+inc+year, data = df, model='pooling')
summary(m_pooled)
# Out:
# Pooling Model
#
# Call:
# plm(formula = value ~ sex + age + age_sq + inc + year, data = df,
#     model = "pooling")
#
# Balanced Panel: n = 16, T = 13, N = 208
#
# Residuals:
#     Min.  1st Qu.   Median  3rd Qu.     Max.
# -5483045 -2524429   974050  1957794  3611759
#
# Coefficients:
#                Estimate  Std. Error t-value  Pr(>|t|)
# (Intercept) -2259423.90   945073.70 -2.3907   0.01773 *
# sex         -2248585.69   358469.38 -6.2727 2.118e-09 ***
# age           503812.61    46527.18 10.8283 < 2.2e-16 ***
# age_sq         -4586.26      564.53 -8.1240 4.422e-14 ***
# inc          7760593.31   534343.54 14.5236 < 2.2e-16 ***
# year          128595.78   388341.83  0.3311   0.74088
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Total Sum of Squares:    8.4048e+15
# Residual Sum of Squares: 1.3498e+15
# R-Squared:      0.83941
# Adj. R-Squared: 0.83543
# F-statistic: 211.165 on 5 and 202 DF, p-value: < 2.22e-16

# %% [markdown]
# #### Модель с фиксированными эффектами

# %%
m_fixed <- plm(value~sex+age+age_sq+inc+year, data = df, model='within')
summary(m_fixed)
# Out:
# Oneway (individual) effect Within Model
#
# Call:
# plm(formula = value ~ sex + age + age_sq + inc + year, data = df,
#     model = "within")
#
# Balanced Panel: n = 16, T = 13, N = 208
#
# Residuals:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
# -272281 -110793  -38580       0   84915  536056
#
# Coefficients:
#      Estimate Std. Error t-value  Pr(>|t|)
# year   128596      25756  4.9928 1.336e-06 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Total Sum of Squares:    6.3467e+12
# Residual Sum of Squares: 5.614e+12
# R-Squared:      0.11545
# Adj. R-Squared: 0.041349
# F-statistic: 24.9284 on 1 and 191 DF, p-value: 1.3364e-06

# %%
summary(fixef(m_fixed, type = "dmean"))
# Out:
#      Estimate     Std. Error t-value      Pr(>|t|)
# 0 18  -4761855.93 64504.32    -73.8222755 2.261687e-142
# 0 26      9396.35 64504.32      0.1456701  8.843355e-01
# 0 35   8683974.44 64504.32    134.6262387 3.185851e-191
# 0 47  11709853.13 64504.32    181.5359423 7.929349e-216
# 0 57  -1596963.73 64504.32    -24.7574681  1.619161e-61
# 0 65   4306232.01 64504.32     66.7588123 2.437653e-134
# 0 7  -10025101.73 64504.32   -155.4175163 4.989655e-203
# 0 77    668808.21 64504.32     10.3684245  2.881522e-20
# 1 18  -4317215.15 64504.32    -66.9290820 1.528594e-134
# 1 26    449308.57 64504.32      6.9655574  5.138536e-11
# 1 35   7266181.44 64504.32    112.6464252 1.273760e-176
# 1 47   8181036.13 64504.32    126.8292681 2.497953e-186
# 1 57  -4302900.56 64504.32    -66.7071652 2.808947e-134
# 1 65   -694119.67 64504.32    -10.7608240  2.057919e-21
# 1 7  -10013692.23 64504.32   -155.2406367 6.191435e-203
# 1 77  -5562941.27 64504.32    -86.2413708 6.786540e-155

# %% [markdown]
# #### Модель со случайными эффектами

# %%
m_random <- plm(value~sex+age+age_sq+inc+year, data = df, model='random')
summary(m_random)
# Out:
# Oneway (individual) effect Random Effect Model
#    (Swamy-Arora's transformation)
#
# Call:
# plm(formula = value ~ sex + age + age_sq + inc + year, data = df,
#     model = "random")
#
# Balanced Panel: n = 16, T = 13, N = 208
#
# Effects:
#                     var   std.dev share
# idiosyncratic 2.939e+10 1.714e+05 0.003
# individual    9.397e+12 3.066e+06 0.997
# theta: 0.9845
#
# Residuals:
#    Min. 1st Qu.  Median 3rd Qu.    Max.
# -255798 -119077  -36413   71164  566094
#
# Coefficients:
#               Estimate Std. Error z-value  Pr(>|z|)
# (Intercept) -2259423.9  2904666.9 -0.7779 0.4366516
# sex         -2248585.7  1532944.3 -1.4668 0.1424193
# age           503812.6   198967.0  2.5321 0.0113368 *
# age_sq         -4586.3     2414.1 -1.8998 0.0574650 .
# inc          7760593.3  2285045.5  3.3963 0.0006832 ***
# year          128595.8    25756.0  4.9928  5.95e-07 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Total Sum of Squares:    8.3668e+12
# Residual Sum of Squares: 5.9373e+12
# R-Squared:      0.29038
# Adj. R-Squared: 0.27281
# Chisq: 82.658 on 5 DF, p-value: 2.3305e-16

# %% [markdown]
# #### Тестирование

# %%
pFtest(m_fixed, m_pooled)
# Out:
# 	F test for individual effects
#
# data:  value ~ sex + age + age_sq + inc + year
# F = 4157.4, df1 = 11, df2 = 191, p-value < 2.2e-16
# alternative hypothesis: significant effects

# %% [markdown]
# Если p-value < 0.05 между Pool и FE выбираем FE model

# %%
phtest(m_fixed, m_random)
# Out:
# 	Hausman Test
#
# data:  value ~ sex + age + age_sq + inc + year
# chisq = 1.5089e-13, df = 1, p-value = 1
# alternative hypothesis: one model is inconsistent

# %% [markdown]
# Если p-value < 0.05 оценки по RE-модели несостоятельны, выбираем FE
# Если p-value > 0.05 оценки по RE-модели и по FE-модели состоятельны, но RE более эффективны, выбираем RE

# %%
plmtest(m_random, effect="individual", type="bp")
# plmtest(m_random, effect="time", type="bp")
# Out:
# 	Lagrange Multiplier Test - (Breusch-Pagan) for balanced panels
#
# data:  value ~ sex + age + age_sq + inc + year
# chisq = 1236.8, df = 1, p-value < 2.2e-16
# alternative hypothesis: significant effects

# %% [markdown]
# Если p-value < 0.05 между Pool и RE выбираем RE model

# %%
# pcdtest(m_random, test = c("lm"))
# pcdtest(m_random, test = "cd")
# pbgtest(m_random, order=3)
# adf.test(df$value, k=1)

# %%
bptest(m_random, data = df, studentize=F)
# Out:
# 	Breusch-Pagan test
#
# data:  m_random
# BP = 15.125, df = 5, p-value = 0.009842

# %% [markdown]
# Есть гетероскдастичность, необходимо использовать устойчивые к гетероскедастичности оценки ковариационной матрицы:

# %%
coeftest(m_random)
# Out:
# t test of coefficients:
#
#               Estimate Std. Error t value  Pr(>|t|)
# (Intercept) -2259423.9  2904666.9 -0.7779 0.4375617
# sex         -2248585.7  1532944.3 -1.4668 0.1439744
# age           503812.6   198967.0  2.5321 0.0120975 *
# age_sq         -4586.3     2414.1 -1.8998 0.0588896 .
# inc          7760593.3  2285045.5  3.3963 0.0008226 ***
# year          128595.8    25756.0  4.9928 1.283e-06 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
# coeftest(m_random, vcovHC(m_random, method="white2", type="HC3"), df = Inf) 
coeftest(m_random, vcovHC(m_random, method="white2", type="HC3"))
# Out:
# t test of coefficients:
#
#               Estimate Std. Error t value  Pr(>|t|)
# (Intercept) -2259423.9  1886011.3 -1.1980 0.2323244
# sex         -2248585.7  1548581.0 -1.4520 0.1480448
# age           503812.6   144635.0  3.4833 0.0006071 ***
# age_sq         -4586.3     1822.7 -2.5161 0.0126429 *
# inc          7760593.3  2306913.4  3.3641 0.0009189 ***
# year          128595.8    26018.8  4.9424 1.617e-06 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %% [markdown]
# ### Все показатели по очереди по той же процедуре

# %%
test_df  <-  data.matrix(matrix(NA,ncol = 5, nrow = length(list_of_pok)))
colnames(test_df)  <-  c('Показатель', 'PvsFE', 'REvsFE', 'PvsRE', 'BPforHC')
for (i in 1:length(list_of_pok)){
    df  <-  list_of_pok[[i]]
    test_df[i,1]  <- df[1,'pok_type']
    df  <-  pdata.frame(df, index = c('group','date'))
    m_pooled <- plm(value~sex+age+age_sq+inc+year, data = df, model='pooling')
    m_fixed <- plm(value~sex+age+age_sq+inc+year, data = df, model='within')
    m_random <- plm(value~sex+age+age_sq+inc+year, data = df, model='random')
    t1  <-  pFtest(m_fixed, m_pooled)
    test_df[i,2]  <- t1$p.value
    t2  <-  phtest(m_fixed, m_random)
    test_df[i,3]  <- t2$p.value
    t3  <-  plmtest(m_random, effect="individual", type="bp")
    test_df[i,4]  <- t3$p.value
    t4  <- bptest(m_random, data = df, studentize=F)
    test_df[i,5]  <- t4$p.value

}

# %%
test_df
# Out:
#       Показатель
#  [1,]  Активные клиенты Total
#  [2,]  Активные клиенты Дебетовые карты
#  [3,]  Объем транзакций cash Дебетовые карты
#  [4,]  Объем транзакций pos Дебетовые карты
#  [5,]  Объем транзакций cash+pos Дебетовые карты
#  [6,]  Остатки на конец месяца Дебетовые карты
#  [7,]  Количество транзакций cash Дебетовые карты
#  [8,]  Количество транзакций pos Дебетовые карты
#  [9,]  Количество транзакций cash+pos Дебетовые карты
# [10,]  Активные клиенты Кредитные карты
# [11,]  Объем транзакций cash Кредитные карты
# [12,]  Объем транзакций pos Кредитные карты
# [13,]  Объем транзакций cash+pos Кредитные карты
# [14,]  Остатки на конец месяца Кредитные карты
# [15,]  Количество транзакций cash Кредитные карты
# [16,]  Количество транзакций pos Кредитные карты
# [17,]  Количество транзакций cash+pos Кредитные карты
# [18,]  Активные клиенты Текущие счета рубли/валюта
# [19,]  Остатки на конец месяца Текущие счета рубли/валюта
# [20,]  Активные клиенты Накопительные счета рубли/валюта
# [21,]  Остатки на конец месяца Накопительные счета рубли/валюта
# [22,]  Активные клиенты Срочные вклады рубли/валюта
# [23,]  Остатки на конец месяца Срочные вклады рубли/валюта
# [24,]  Активные клиенты Ипотека
# [25,]  Портфель Ипотека
# [26,]  Выдачи Ипотека
# [27,]  Активные клиенты Кредиты наличными
# [28,]  Портфель Кредиты наличными
# [29,]  Выдачи Кредиты наличными
# [30,]  Активные клиенты POS
# [31,]  Портфель POS
# [32,]  Выдачи POS
# [33,]  Активные клиенты Авто
# [34,]  Портфель Авто
# [35,]  Выдачи Авто
#       PvsFE                 REvsFE            PvsRE
#  [1,] 7.14620006824094e-221 0.99999969006951  6.19925406132562e-271
#  [2,] 6.59139098682611e-195 0.999999398438329 8.05743585272513e-269
#  [3,] 2.50593185985744e-87  0.999999781415922 2.21128120246056e-215
#  [4,] 1.43018695082392e-68  0.999999831858401 4.35106139838782e-185
#  [5,] 5.06571407772464e-81  0.999999922508091 1.81398971823718e-206
#  [6,] 5.07200569600703e-123 0.999999992480479 4.48378693883967e-248
#  [7,] 8.73666085619077e-86  0.999999643317806 2.61092375788488e-213
#  [8,] 2.97516040048884e-55  0.999999809769497 8.42725888369734e-156
#  [9,] 6.28413324418261e-57  0.999999967375738 7.02595318986781e-160
# [10,] 6.69327262893468e-205 0.999999446015288 8.59789091174654e-270
# [11,] 1.47791823490693e-135 0.984932742388341 3.6654674920603e-251
# [12,] 6.1425115776124e-117  0.999999697345123 3.50459607994284e-244
# [13,] 1.14409880502943e-124 0.999999889486064 4.87565908965662e-249
# [14,] 8.47748169405577e-154 0.999999506248599 3.46457773316712e-261
# [15,] 5.58241805739018e-137 0.98502760162384  4.37512173207982e-251
# [16,] 9.43508461654502e-93  0.999999484365764 3.77660138652406e-222
# [17,] 1.6507651421686e-93   0.999999563581295 4.94287191026214e-223
# [18,] 4.2952367685891e-196  0.999999368360246 6.00265258527844e-269
# [19,] 7.81275108180774e-177 0.999999895625727 2.38633825558434e-266
# [20,] 2.2987534516194e-106  0.998763375613038 3.35949564599239e-235
# [21,] 7.0042281760583e-139  0.998669615676928 7.35137314241198e-253
# [22,] 2.09036121389215e-260 0.999999663467796 1.97252088356941e-272
# [23,] 6.26279883585605e-213 0.99999901153331  2.02197113671801e-270
# [24,] 8.84513246516724e-226 0.999999766692802 3.3167693802144e-271
# [25,] 1.68720384584001e-185 0.999999809769497 1.14754175990404e-267
# [26,] 4.84089375520467e-52  0.999999702242164 6.78714949056287e-144
# [27,] 1.96710758811015e-243 0.99999966023191  5.89455301611449e-272
# [28,] 5.31505537294845e-145 0.999999669531936 2.40789805513057e-258
# [29,] 3.57592485443441e-53  0.999999655924355 1.70428310756033e-146
# [30,] 1.48696245705444e-81  0.999999404484329 2.40096017648028e-194
# [31,] 1.41570204461051e-74  0.999999615596287 2.46442219810236e-185
# [32,] 1.70426669863647e-17  0.99999994955752  2.3833142084373e-39
# [33,] 6.19601679894073e-222 0.980301067231935 1.08042902682402e-229
# [34,] 3.0062761704462e-159  0.972892507001578 1.30058556174772e-226
# [35,] 2.92477724354601e-59  0.998775367572346 2.05672487060446e-149
#       BPforHC
#  [1,] 0.00984164980988673
#  [2,] 2.45383029502883e-05
#  [3,] 6.17029553278304e-17
#  [4,] 1.0062546810454e-26
#  [5,] 1.8586971223819e-20
#  [6,] 0.00131570527792829
#  [7,] 6.4957535180502e-07
#  [8,] 9.75615568590538e-08
#  [9,] 4.13756063021227e-08
# [10,] 3.35606804129358e-21
# [11,] 2.11103616854678e-22
# [12,] 1.14913166131695e-27
# [13,] 5.90233065262668e-27
# [14,] 2.76395996833937e-26
# [15,] 2.92533937323688e-17
# [16,] 8.17027438315096e-25
# [17,] 1.04504373369556e-24
# [18,] 2.54872074123485e-10
# [19,] 7.3471670520269e-11
# [20,] 2.29039721557844e-17
# [21,] 9.65323643910207e-11
# [22,] 3.07219916985692e-07
# [23,] 0.000562227444333556
# [24,] 1.10301351505661e-34
# [25,] 5.00563316744061e-36
# [26,] 2.69862989837859e-25
# [27,] 7.46730235849189e-16
# [28,] 7.72854359298826e-24
# [29,] 4.26328307700875e-13
# [30,] 6.14673091559156e-15
# [31,] 6.76248101566766e-18
# [32,] 2.93148639303942e-18
# [33,] 1.1435973734644e-10
# [34,] 1.46632842145358e-11
# [35,] 8.09825666883705e-06

# %%
cf1  <- coeftest(m_random) 
coef_df  <-  data.matrix(matrix(NA,nrow = 6, ncol = length(list_of_pok)))
pvalue_df  <-  data.matrix(matrix(NA,nrow = 6, ncol = length(list_of_pok)))
pvalue_hc_df  <-  data.matrix(matrix(NA,nrow = 6, ncol = length(list_of_pok)))
colnames(coef_df)  <- colnames(pvalue_df)  <-  colnames(pvalue_hc_df)  <-  test_df[,1]
rownames(coef_df)  <- rownames(pvalue_df)  <-  rownames(pvalue_hc_df)  <-  rownames(cf1)

for (i in 1:length(list_of_pok)){
    df  <-  list_of_pok[[i]]
    test_df[i,1]  <- df[1,'pok_type']
    df  <-  pdata.frame(df, index = c('group','date'))
    m_random <- plm(value~sex+age+age_sq+inc+year, data = df, model='random')
    cf1  <- coeftest(m_random) 
    coef_df[,i]  <- cf1[,1]
    pvalue_df[,i]  <- cf1[,4]
    cf2  <- coeftest(m_random, vcovHC(m_random, method="white2", type="HC3")) 
    pvalue_hc_df[,i]  <- cf2[,4]
}

# %%
coef_df
# Out:
#              Активные клиенты Total  Активные клиенты Дебетовые карты
# (Intercept) -2259423.897            -3805532.042
# sex         -2248585.686            -1530708.025
# age           503812.614              592384.146
# age_sq         -4586.263               -6357.349
# inc          7760593.306             5554997.770
# year          128595.781              217834.034
#              Объем транзакций cash Дебетовые карты
# (Intercept) -113135129293
# sex           33706554721
# age           10997502611
# age_sq         -112831609
# inc          146397917051
# year         -10543225634
#              Объем транзакций pos Дебетовые карты
# (Intercept) -64226620284
# sex            223987785
# age           6164236620
# age_sq         -68551796
# inc         136072083414
# year          7009808002
#              Объем транзакций cash+pos Дебетовые карты
# (Intercept) -177361749577
# sex           33930542506
# age           17161739232
# age_sq         -181383405
# inc          282470000464
# year          -3533417632
#              Остатки на конец месяца Дебетовые карты
# (Intercept) -239189569161
# sex            9233909321
# age           20794308356
# age_sq         -199298309
# inc           86901243276
# year           4879163247
#              Количество транзакций cash Дебетовые карты
# (Intercept) -9104421.84
# sex         -2691948.13
# age          1573334.38
# age_sq        -16964.67
# inc         13718837.19
# year        -1080467.70
#              Количество транзакций pos Дебетовые карты
# (Intercept) -70012092.9
# sex         -26569361.7
# age          10541946.0
# age_sq        -126984.4
# inc         189472735.4
# year         22799900.2
#              Количество транзакций cash+pos Дебетовые карты
# (Intercept) -79116514.8
# sex         -29261309.9
# age          12115280.4
# age_sq        -143949.1
# inc         203191572.6
# year         21719432.5
#              Активные клиенты Кредитные карты ⋯  Выдачи Ипотека
# (Intercept) -1526065.288                      ⋯ -2354650718
# sex          -429452.400                      ⋯  1705220241
# age           133827.434                      ⋯   820650765
# age_sq         -1415.558                      ⋯    -8979450
# inc          2015896.701                      ⋯ 30453360142
# year          103634.458                      ⋯ -5942362018
#              Активные клиенты Кредиты наличными  Портфель Кредиты наличными
# (Intercept) -1165537.366                        -388469339690
# sex          -259205.819                          31043954762
# age           113117.509                          25824287520
# age_sq         -1204.132                           -276127524
# inc          1296421.270                         477509605204
# year           10069.820                          36376839795
#              Выдачи Кредиты наличными  Активные клиенты POS  Портфель POS
# (Intercept) -45397318868              319752.92536           8199305778
# sex          -3478904814              -86524.30807          -1768572999
# age           2859263586                1022.26521            -11782478
# age_sq         -29545542                 -61.81106             -1275068
# inc          29146965000              910033.67938          21609794193
# year           177575477               57404.76424           1562910701
#              Выдачи POS   Активные клиенты Авто  Портфель Авто  Выдачи Авто
# (Intercept) 1675668696.5 -275512.9340           -153003223269  -16169366684
# sex         -320091890.5   70539.8001             35750246495    2419869404
# age            4502693.5   13887.0192              7214883293     969797858
# age_sq         -237258.2    -141.9059               -73361890     -11474194
# inc         2610636906.0  148335.8630             81100054751    2943220573
# year        -175191435.9   -2542.1598              3152047808     -79517984

# %%
pv  <- pvalue_df
pv[pvalue_df>=0.1]  <-  ''
pv[pvalue_df<0.1] <-  '.'
pv[pvalue_df<0.05] <-  '*'
pv[pvalue_df<0.01] <-  '**'
pv[pvalue_df<0.001] <-  '***'

# %%
pv1  <- pvalue_hc_df
pv1[pvalue_hc_df>=0.1]  <-  ''
pv1[pvalue_hc_df<0.1] <-  '.'
pv1[pvalue_hc_df<0.05] <-  '*'
pv1[pvalue_hc_df<0.01] <-  '**'
pv1[pvalue_hc_df<0.001] <-  '***'

# %%
cpv  <-  rbind(coef_df, pv)
cpv_hc <-  rbind(coef_df, pv1)

# %%
cpv[c(1,7,2,8,3,9,4,10,5,11,6,12),]
cpv_hc[c(1,7,2,8,3,9,4,10,5,11,6,12),]
# Out:
#              Активные клиенты Total  Активные клиенты Дебетовые карты
# (Intercept) -2259423.89730176       -3805532.04184176
# (Intercept)                         .
# sex         -2248585.68579219       -1530708.02467134
# sex
# age         503812.614260797        592384.146049009
# age         *                       ***
# age_sq      -4586.26266778375       -6357.34934861266
# age_sq      .                       ***
# inc         7760593.30641418        5554997.77007233
# inc         ***                     **
# year        128595.780896652        217834.033562434
# year        ***                     ***
#              Объем транзакций cash Дебетовые карты
# (Intercept) -113135129293.302
# (Intercept) .
# sex         33706554721.4043
# sex
# age         10997502611.3248
# age         *
# age_sq      -112831608.603712
# age_sq      *
# inc         146397917050.566
# inc         **
# year        -10543225633.5075
# year        ***
#              Объем транзакций pos Дебетовые карты
# (Intercept) -64226620283.7832
# (Intercept) .
# sex         223987785.025705
# sex
# age         6164236620.2024
# age         **
# age_sq      -68551796.2976063
# age_sq      *
# inc         136072083413.834
# inc         ***
# year        7009808001.86961
# year        ***
#              Объем транзакций cash+pos Дебетовые карты
# (Intercept) -177361749577.086
# (Intercept) .
# sex         33930542506.4298
# sex
# age         17161739231.5273
# age         **
# age_sq      -181383404.901319
# age_sq      *
# inc         282470000464.398
# inc         ***
# year        -3533417631.63793
# year
#              Остатки на конец месяца Дебетовые карты
# (Intercept) -239189569160.974
# (Intercept) *
# sex         9233909321.29406
# sex
# age         20794308355.7177
# age         **
# age_sq      -199298308.669093
# age_sq      *
# inc         86901243276.2881
# inc
# year        4879163247.05008
# year
#              Количество транзакций cash Дебетовые карты
# (Intercept) -9104421.8375058
# (Intercept)
# sex         -2691948.12649835
# sex
# age         1573334.38217045
# age         ***
# age_sq      -16964.6735754481
# age_sq      ***
# inc         13718837.1899923
# inc         **
# year        -1080467.69961178
# year        ***
#              Количество транзакций pos Дебетовые карты
# (Intercept) -70012092.922885
# (Intercept)
# sex         -26569361.7297366
# sex
# age         10541946.017602
# age         ***
# age_sq      -126984.441043597
# age_sq      ***
# inc         189472735.384535
# inc         ***
# year        22799900.2493275
# year        ***
#              Количество транзакций cash+pos Дебетовые карты
# (Intercept) -79116514.7603907
# (Intercept)
# sex         -29261309.8562345
# sex
# age         12115280.3997725
# age         ***
# age_sq      -143949.114619046
# age_sq      ***
# inc         203191572.574527
# inc         ***
# year        21719432.5497159
# year        ***
#              Активные клиенты Кредитные карты ⋯  Выдачи Ипотека
# (Intercept) -1526065.28838973                 ⋯ -2354650718.48678
# (Intercept) .                                 ⋯
# sex         -429452.400427839                 ⋯ 1705220241.37557
# sex                                           ⋯
# age         133827.433731407                  ⋯ 820650765.179856
# age         *                                 ⋯
# age_sq      -1415.55787908434                 ⋯ -8979450.05592522
# age_sq      .                                 ⋯
# inc         2015896.7006482                   ⋯ 30453360142.4257
# inc         **                                ⋯ ***
# year        103634.457865442                  ⋯ -5942362018.08365
# year        ***                               ⋯ ***
#              Активные клиенты Кредиты наличными  Портфель Кредиты наличными
# (Intercept) -1165537.36637852                   -388469339690.202
# (Intercept) .                                   .
# sex         -259205.818800783                   31043954762.4448
# sex
# age         113117.509395427                    25824287519.7626
# age         *                                   .
# age_sq      -1204.13186631094                   -276127523.852074
# age_sq      *                                   .
# inc         1296421.27004587                    477509605203.622
# inc         *                                   **
# year        10069.8199683397                    36376839795.0492
# year        *                                   ***
#              Выдачи Кредиты наличными  Активные клиенты POS  Портфель POS
# (Intercept) -45397318867.8216         319752.925356052      8199305778.01858
# (Intercept) **
# sex         -3478904814.11538         -86524.3080674836     -1768572999.43091
# sex
# age         2859263585.62642          1022.26521205705      -11782478.3281858
# age         **
# age_sq      -29545542.261833          -61.8110602315512     -1275068.03807531
# age_sq      **
# inc         29146964999.6048          910033.679376208      21609794193.3698
# inc         ***                       ***                   ***
# year        177575477.285945          57404.7642371912      1562910701.47345
# year                                  ***                   ***
#              Выдачи POS        Активные клиенты Авто  Портфель Авто
# (Intercept) 1675668696.46716  -275512.934004865      -153003223269.34
# (Intercept) *                 *                      *
# sex         -320091890.528735 70539.8001352723       35750246494.6111
# sex                           .
# age         4502693.46061301  13887.0192034206       7214883293.14476
# age                           *                      .
# age_sq      -237258.238461475 -141.905868130057      -73361889.5163673
# age_sq                        .                      .
# inc         2610636906.00913  148335.863010851       81100054751.4799
# inc         ***               *                      *
# year        -175191435.873505 -2542.15981086887      3152047807.86681
# year        **                ***                    ***
#              Выдачи Авто
# (Intercept) -16169366684.4748
# (Intercept)
# sex         2419869404.05291
# sex
# age         969797857.930549
# age
# age_sq      -11474193.9094393
# age_sq
# inc         2943220572.72885
# inc
# year        -79517983.7587711
# year
#              Активные клиенты Total  Активные клиенты Дебетовые карты
# (Intercept) -2259423.89730176       -3805532.04184176
# (Intercept)                         *
# sex         -2248585.68579219       -1530708.02467134
# sex
# age         503812.614260797        592384.146049009
# age         ***                     ***
# age_sq      -4586.26266778375       -6357.34934861266
# age_sq      *                       ***
# inc         7760593.30641418        5554997.77007233
# inc         ***                     **
# year        128595.780896652        217834.033562434
# year        ***                     ***
#              Объем транзакций cash Дебетовые карты
# (Intercept) -113135129293.302
# (Intercept) **
# sex         33706554721.4043
# sex
# age         10997502611.3248
# age         ***
# age_sq      -112831608.603712
# age_sq      ***
# inc         146397917050.566
# inc         **
# year        -10543225633.5075
# year        ***
#              Объем транзакций pos Дебетовые карты
# (Intercept) -64226620283.7832
# (Intercept) ***
# sex         223987785.025705
# sex
# age         6164236620.2024
# age         ***
# age_sq      -68551796.2976063
# age_sq      ***
# inc         136072083413.834
# inc         ***
# year        7009808001.86961
# year        ***
#              Объем транзакций cash+pos Дебетовые карты
# (Intercept) -177361749577.086
# (Intercept) ***
# sex         33930542506.4298
# sex
# age         17161739231.5273
# age         ***
# age_sq      -181383404.901319
# age_sq      ***
# inc         282470000464.398
# inc         ***
# year        -3533417631.63793
# year
#              Остатки на конец месяца Дебетовые карты
# (Intercept) -239189569160.974
# (Intercept) ***
# sex         9233909321.29406
# sex
# age         20794308355.7177
# age         ***
# age_sq      -199298308.669093
# age_sq      ***
# inc         86901243276.2881
# inc
# year        4879163247.05008
# year
#              Количество транзакций cash Дебетовые карты
# (Intercept) -9104421.8375058
# (Intercept) **
# sex         -2691948.12649835
# sex
# age         1573334.38217045
# age         ***
# age_sq      -16964.6735754481
# age_sq      ***
# inc         13718837.1899923
# inc         **
# year        -1080467.69961178
# year        ***
#              Количество транзакций pos Дебетовые карты
# (Intercept) -70012092.922885
# (Intercept) *
# sex         -26569361.7297366
# sex
# age         10541946.017602
# age         ***
# age_sq      -126984.441043597
# age_sq      ***
# inc         189472735.384535
# inc         ***
# year        22799900.2493275
# year        ***
#              Количество транзакций cash+pos Дебетовые карты
# (Intercept) -79116514.7603907
# (Intercept) **
# sex         -29261309.8562345
# sex
# age         12115280.3997725
# age         ***
# age_sq      -143949.114619046
# age_sq      ***
# inc         203191572.574527
# inc         ***
# year        21719432.5497159
# year        ***
#              Активные клиенты Кредитные карты ⋯  Выдачи Ипотека
# (Intercept) -1526065.28838973                 ⋯ -2354650718.48678
# (Intercept) *                                 ⋯
# sex         -429452.400427839                 ⋯ 1705220241.37557
# sex                                           ⋯
# age         133827.433731407                  ⋯ 820650765.179856
# age         **                                ⋯
# age_sq      -1415.55787908434                 ⋯ -8979450.05592522
# age_sq      **                                ⋯
# inc         2015896.7006482                   ⋯ 30453360142.4257
# inc         **                                ⋯ ***
# year        103634.457865442                  ⋯ -5942362018.08365
# year        ***                               ⋯ ***
#              Активные клиенты Кредиты наличными  Портфель Кредиты наличными
# (Intercept) -1165537.36637852                   -388469339690.202
# (Intercept) ***                                 **
# sex         -259205.818800783                   31043954762.4448
# sex
# age         113117.509395427                    25824287519.7626
# age         **                                  ***
# age_sq      -1204.13186631094                   -276127523.852074
# age_sq      **                                  **
# inc         1296421.27004587                    477509605203.622
# inc         *                                   ***
# year        10069.8199683397                    36376839795.0492
# year        *                                   ***
#              Выдачи Кредиты наличными  Активные клиенты POS  Портфель POS
# (Intercept) -45397318867.8216         319752.925356052      8199305778.01858
# (Intercept) ***                       .                     .
# sex         -3478904814.11538         -86524.3080674836     -1768572999.43091
# sex
# age         2859263585.62642          1022.26521205705      -11782478.3281858
# age         ***
# age_sq      -29545542.261833          -61.8110602315512     -1275068.03807531
# age_sq      ***
# inc         29146964999.6048          910033.679376208      21609794193.3698
# inc         ***                       ***                   ***
# year        177575477.285945          57404.7642371912      1562910701.47345
# year                                  ***                   ***
#              Выдачи POS        Активные клиенты Авто  Портфель Авто
# (Intercept) 1675668696.46716  -275512.934004865      -153003223269.34
# (Intercept) ***               **                     *
# sex         -320091890.528735 70539.8001352723       35750246494.6111
# sex                           .
# age         4502693.46061301  13887.0192034206       7214883293.14476
# age                           **                     **
# age_sq      -237258.238461475 -141.905868130057      -73361889.5163673
# age_sq                        **                     **
# inc         2610636906.00913  148335.863010851       81100054751.4799
# inc         ***               **                     **
# year        -175191435.873505 -2542.15981086887      3152047807.86681
# year        **                ***                    ***
#              Выдачи Авто
# (Intercept) -16169366684.4748
# (Intercept) *
# sex         2419869404.05291
# sex
# age         969797857.930549
# age         **
# age_sq      -11474193.9094393
# age_sq      **
# inc         2943220572.72885
# inc         .
# year        -79517983.7587711
# year

# %%
write.csv(cpv_hc[c(1,7,2,8,3,9,4,10,5,11,6,12),],'cpv.csv')
