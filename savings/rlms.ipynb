# %%
import pyreadstat

# %%
df, meta = pyreadstat.read_sav("/home/xenakas/Downloads/r25h_os26c.sav")

# %%
df
# Out:
#       UREDID_H       UID_H      TID_H      SID_H      RID_H      QID_H  \
# 0       1471.0     10003.0    10003.0    10003.0    10003.0    10003.0
# 1       1468.0     10004.0    10004.0    10004.0    10004.0    10004.0
# 2       1469.0     10012.0    10012.0    10012.0    10012.0    10012.0
# 3       1373.0     10014.0    10014.0    10014.0    10014.0    10014.0
# 4       1366.0     10016.0    10016.0    10016.0    10016.0    10016.0
# 5       1455.0     10024.0    10024.0    10024.0    10024.0    10024.0
# 6       2812.0     10029.0        NaN    10029.0    10029.0    10029.0
# 7       1367.0     10035.0    10035.0    10035.0        NaN        NaN
# 8       1369.0     10036.0    10036.0    10036.0    10036.0    10036.0
# 9       1374.0     10037.0    10037.0    10037.0    10037.0    10037.0
# 10      1377.0     10038.0    10038.0    10038.0        NaN    10038.0
# 11      1482.0     10040.0    10040.0    10040.0    10040.0    10040.0
# ...

# %%
meta
